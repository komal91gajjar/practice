# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\excel data\\dataset_olympics.csv")
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
df.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2732
# Height    16254
# Weight    17101
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     60310
# dtype: int64

# %%
df.isnull()
# Out:
#           ID   Name    Sex    Age  Height  Weight   Team    NOC  Games   Year  \
# 0      False  False  False  False   False   False  False  False  False  False
# 1      False  False  False  False   False   False  False  False  False  False
# 2      False  False  False  False    True    True  False  False  False  False
# 3      False  False  False  False    True    True  False  False  False  False
# 4      False  False  False  False   False   False  False  False  False  False
# ...      ...    ...    ...    ...     ...     ...    ...    ...    ...    ...
# 69995  False  False  False  False    True    True  False  False  False  False
# 69996  False  False  False  False    True    True  False  False  False  False
# 69997  False  False  False  False   False   False  False  False  False  False
# 69998  False  False  False  False   False   False  False  False  False  False
# 69999  False  False  False  False   False   False  False  False  False  False
#
# ...

# %%
df.fillna("Gold")
# Out:
#           ID                            Name Sex   Age Height Weight  \
# 0          1                       A Dijiang   M  24.0  180.0   80.0
# 1          2                        A Lamusi   M  23.0  170.0   60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0   Gold   Gold
# 3          4            Edgar Lindenau Aabye   M  34.0   Gold   Gold
# 4          5        Christine Jacoba Aaftink   F  21.0  185.0   82.0
# ...      ...                             ...  ..   ...    ...    ...
# 69995  35656              Stuart Fitzsimmons   M  19.0   Gold   Gold
# 69996  35656              Stuart Fitzsimmons   M  19.0   Gold   Gold
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0  170.0   65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0  170.0   65.0
# 69999  35658                    Marek Fiurek   M  23.0  180.0   68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# 0               China  CHN  1992 Summer  1992  Summer  Barcelona
# ...

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
column_deleted = ["Sex","Age","Height","Weight","NOC","Year","Season"]# multipal column deleted

df.drop(columns= column_deleted, inplace=True)

# %%
df
# Out:
#           ID                            Name            Team        Games  \
# 0          1                       A Dijiang           China  1992 Summer
# 1          2                        A Lamusi           China  2012 Summer
# 2          3             Gunnar Nielsen Aaby         Denmark  1920 Summer
# 3          4            Edgar Lindenau Aabye  Denmark/Sweden  1900 Summer
# 4          5        Christine Jacoba Aaftink     Netherlands  1988 Winter
# ...      ...                             ...             ...          ...
# 69995  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69996  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69997  35657  David Thomas "Dave" Fitzsimons       Australia  1976 Summer
# 69998  35657  David Thomas "Dave" Fitzsimons       Australia  1980 Summer
# 69999  35658                    Marek Fiurek  Czech Republic  1998 Winter
#
#             City            Sport                             Event Medal
# ...

# %%
columns_with_nulls = df.columns[df.isnull().any()]

print("Columns with null values:", columns_with_nulls)
# Out:
# Columns with null values: Index(['Medal'], dtype='object')

# %%
df.loc["china"] = "Gold"
df.drop("china")
# Out:
#           ID                            Name            Team        Games  \
# 0          1                       A Dijiang           China  1992 Summer
# 1          2                        A Lamusi           China  2012 Summer
# 2          3             Gunnar Nielsen Aaby         Denmark  1920 Summer
# 3          4            Edgar Lindenau Aabye  Denmark/Sweden  1900 Summer
# 4          5        Christine Jacoba Aaftink     Netherlands  1988 Winter
# ...      ...                             ...             ...          ...
# 69995  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69996  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69997  35657  David Thomas "Dave" Fitzsimons       Australia  1976 Summer
# 69998  35657  David Thomas "Dave" Fitzsimons       Australia  1980 Summer
# 69999  35658                    Marek Fiurek  Czech Republic  1998 Winter
#
#             City            Sport                             Event Medal
# ...

# %%
df.drop("china", inplace = True)

# %%
df
# Out:
#           ID                            Name            Team        Games  \
# 0          1                       A Dijiang           China  1992 Summer
# 1          2                        A Lamusi           China  2012 Summer
# 2          3             Gunnar Nielsen Aaby         Denmark  1920 Summer
# 3          4            Edgar Lindenau Aabye  Denmark/Sweden  1900 Summer
# 4          5        Christine Jacoba Aaftink     Netherlands  1988 Winter
# ...      ...                             ...             ...          ...
# 69995  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69996  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69997  35657  David Thomas "Dave" Fitzsimons       Australia  1976 Summer
# 69998  35657  David Thomas "Dave" Fitzsimons       Australia  1980 Summer
# 69999  35658                    Marek Fiurek  Czech Republic  1998 Winter
#
#             City            Sport                             Event Medal
# ...

# %%
#df["Team"].fillna("Gold", inplace=True)

# %%
df
# Out:
#           ID                            Name            Team        Games  \
# 0          1                       A Dijiang           China  1992 Summer
# 1          2                        A Lamusi           China  2012 Summer
# 2          3             Gunnar Nielsen Aaby         Denmark  1920 Summer
# 3          4            Edgar Lindenau Aabye  Denmark/Sweden  1900 Summer
# 4          5        Christine Jacoba Aaftink     Netherlands  1988 Winter
# ...      ...                             ...             ...          ...
# 69995  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69996  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69997  35657  David Thomas "Dave" Fitzsimons       Australia  1976 Summer
# 69998  35657  David Thomas "Dave" Fitzsimons       Australia  1980 Summer
# 69999  35658                    Marek Fiurek  Czech Republic  1998 Winter
#
#             City            Sport                             Event Medal
# ...

# %%
birds_data.replace({"birds": "spoonbills", "priority": "yes"}, {"birds": "OWL", "priority": "right"}, inplace=True)

# %%
df.replace({"Team" : "China", "Medal" : " "}, {"Team" : "China", "Medal" : "Gold"}, inplace = True)

# %%
df
# Out:
#           ID                            Name            Team        Games  \
# 0          1                       A Dijiang           China  1992 Summer
# 1          2                        A Lamusi           China  2012 Summer
# 2          3             Gunnar Nielsen Aaby         Denmark  1920 Summer
# 3          4            Edgar Lindenau Aabye  Denmark/Sweden  1900 Summer
# 4          5        Christine Jacoba Aaftink     Netherlands  1988 Winter
# ...      ...                             ...             ...          ...
# 69995  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69996  35656              Stuart Fitzsimmons   Great Britain  1976 Winter
# 69997  35657  David Thomas "Dave" Fitzsimons       Australia  1976 Summer
# 69998  35657  David Thomas "Dave" Fitzsimons       Australia  1980 Summer
# 69999  35658                    Marek Fiurek  Czech Republic  1998 Winter
#
#             City            Sport                             Event Medal
# ...

# %%
plt.pie(df["Medal"],labels = df["Team"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 plt.pie(df["Medal"],labels = df["Team"])
#       2 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
df = pd.read_csv("D:\\excel data\\flipkartdata.csv")

# %%
df
# Out:
#          id                                              title  Rating  \
# 0      2242                            Casuals For Men  (Blue)     3.8
# 1     20532                           Women Black Flats Sandal     3.9
# 2     10648                           Women Gold Wedges Sandal     3.9
# 3     20677  Men's Height Increasing High Heel Formal Party...     3.9
# 4     12593                             Loafers For Men  (Tan)     3.9
# ...     ...                                                ...     ...
# 5239  14033                       Women Off White Flats Sandal     NaN
# 5240    297                             Slip On For Men  (Tan)     3.9
# 5241  18733                            Women Grey Heels Sandal     3.8
# 5242   6162  Womens Casual Comfort Stylish Black High Heel ...     3.9
# 5243  13574    ZAPATOZ Women's Casual PU Leather Sneaker Shoes     3.9
#
#      maincateg  platform  actprice1  norating1  noreviews1  star_5f  star_4f  \
# ...

# %%
title = df["title"]
rating = df["Rating"]
maincateg = df["maincateg"]
platform = df["platform"]
actprice1 = df["actprice1"]
norating1 = df["norating1"]
noreviews1 = df["noreviews1"]
star_5f = df["star_5f"]
star_1f = df["star_1f"]
fulfilled1 = df["fulfilled1"]

colors = ["hotpink", "lightgreen"]
plt.bar(platform,actprice1, color = colors)
plt.xlabel("platform",size = 20)
plt.ylabel("Actual price",size = 20)
plt.title("Online shopping", size = 20, color = "red")
#plt.grid()
plt.show()

# %%
# plot 1
plt.scatter(platform,star_5f)

plt.xlabel("platform",size = 20)
plt.ylabel("five star of product",size = 20)
plt.title("scatter plot 1",size = 20)

plt.grid()

plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(actprice1)
plt.show()

# %%
#plot 1 

plt.hist(star_1f, color = "r")
plt.xlabel("x data")
plt.title("plot 1")
(plt.show())

#plot 2
plt.hist(star_5f, color = "yellow")
plt.ylabel("y data")
plt.title("plot 2")

plt.show()

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# Rating        203
# maincateg       2
# platform        0
# actprice1       0
# norating1       0
# noreviews1      0
# star_5f        68
# star_4f         0
# star_3f         0
# star_2f         0
# star_1f       186
# fulfilled1      0
# dtype: int64

# %%
df.isnull()
# Out:
#          id  title  Rating  maincateg  platform  actprice1  norating1  \
# 0     False  False   False      False     False      False      False
# 1     False  False   False      False     False      False      False
# 2     False  False   False      False     False      False      False
# 3     False  False   False      False     False      False      False
# 4     False  False   False      False     False      False      False
# ...     ...    ...     ...        ...       ...        ...        ...
# 5239  False  False    True      False     False      False      False
# 5240  False  False   False      False     False      False      False
# 5241  False  False   False      False     False      False      False
# 5242  False  False   False      False     False      False      False
# 5243  False  False   False      False     False      False      False
#
#       noreviews1  star_5f  star_4f  star_3f  star_2f  star_1f  fulfilled1
# ...

# %%
#df.dropna(inplace = True)
df.dropna(inplace=True)

# %%
df
# Out:
#          id                                              title  Rating  \
# 0      2242                            Casuals For Men  (Blue)     3.8
# 1     20532                           Women Black Flats Sandal     3.9
# 2     10648                           Women Gold Wedges Sandal     3.9
# 3     20677  Men's Height Increasing High Heel Formal Party...     3.9
# 4     12593                             Loafers For Men  (Tan)     3.9
# ...     ...                                                ...     ...
# 5238  12515             Training & Gym Shoes For Women  (Pink)     4.3
# 5240    297                             Slip On For Men  (Tan)     3.9
# 5241  18733                            Women Grey Heels Sandal     3.8
# 5242   6162  Womens Casual Comfort Stylish Black High Heel ...     3.9
# 5243  13574    ZAPATOZ Women's Casual PU Leather Sneaker Shoes     3.9
#
#      maincateg  platform  actprice1  norating1  noreviews1  star_5f  star_4f  \
# ...

# %%
df.isnull().sum()
# Out:
# id            0
# title         0
# Rating        0
# maincateg     0
# platform      0
# actprice1     0
# norating1     0
# noreviews1    0
# star_5f       0
# star_4f       0
# star_3f       0
# star_2f       0
# star_1f       0
# fulfilled1    0
# dtype: int64

# %%
plt.scatter(x = "Rating", y = "actprice1", marker = "*",data = df)

plt.grid(linestyle = "-",linewidth = 1)

plt.show()

# %%
df
# Out:
#          id                                              title  Rating  \
# 0      2242                            Casuals For Men  (Blue)     3.8
# 1     20532                           Women Black Flats Sandal     3.9
# 2     10648                           Women Gold Wedges Sandal     3.9
# 3     20677  Men's Height Increasing High Heel Formal Party...     3.9
# 4     12593                             Loafers For Men  (Tan)     3.9
# ...     ...                                                ...     ...
# 5238  12515             Training & Gym Shoes For Women  (Pink)     4.3
# 5240    297                             Slip On For Men  (Tan)     3.9
# 5241  18733                            Women Grey Heels Sandal     3.8
# 5242   6162  Womens Casual Comfort Stylish Black High Heel ...     3.9
# 5243  13574    ZAPATOZ Women's Casual PU Leather Sneaker Shoes     3.9
#
#      maincateg  platform  actprice1  norating1  noreviews1  star_5f  star_4f  \
# ...

# %%
plt.scatter(x = "platform", y = "actprice1")
plt.grid(linestyle = "-",linewidth = 2)
plt.show()
