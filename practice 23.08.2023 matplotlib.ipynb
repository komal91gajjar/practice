# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# #  matplotlib line

# %%
xpoints = np.array([2,4,6,8,10])
ypoints = np.array([3,6,9,12,15])

plt.plot(xpoints,ypoints, marker = "*", markersize = 5, color = "r", linestyle = "-")
#plt.plot(xpoints, ypoints, marker='*', markersize=5, color='r', linestyle='-')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xpoints = np.array([2, 4, 6, 8, 10])
ypoints = np.array([3, 6, 9, 12, 15])

plt.plot(xpoints, ypoints, marker='*', markersize=5, color='r', linestyle='-')
plt.show()

# %%
xpoints = np.array([50,55,60,65,70,75])

plt.plot(xpoints, marker = "<", markersize = 15, color = "b", markerfacecolor = "r", linestyle = "--", linewidth = 3)
plt.show()

# %%
'''data = {
    "name" : ["pooja", "aashish"],
    "age" : [10,20]
}
df = pd.DataFrame(data)'''

Duration = df["Duration"]
Pulse = df["Pulse"]
Calories = df["Calories"]

df= pd.read_csv("data.csv")
df

plt.plot(Duration,Pulse, marker = ">", markerfacecolor = "r", linestyle = "--", linewidth = 3.5, markersize = 10)
#plt.plot(Duration,Calories, marker  = "<",markerfacecolor = "b",linestyle = "-",linewidth = 4.5,markersize = 15)

plt.xlabel("Duration",size = 25)
plt.ylabel("Pulse",size = 25)
plt.title(" data of pulse",size = 20,)
plt.grid()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv("data.csv")

# Extract data from the DataFrame
Duration = df["Duration"]
Pulse = df["Pulse"]
Calories = df["Calories"]

# Create a plot
plt.plot(Duration, Pulse, marker=">", markerfacecolor="r", linestyle="--", linewidth=3.5, markersize=5, label="Pulse", color="r")
plt.plot(Duration, Calories, marker="<", markerfacecolor="b", linestyle="-", linewidth=4.5, markersize=10, label="Calories", color="b")

# Add labels, title, and legend
plt.xlabel("Duration",color = "r",size = 20)
plt.ylabel("Value",color = "r",size = 20)
plt.title("Pulse and Calories Over Time",color = "b",size = 10, loc = "center")

#plt.grid(axis = "x")
#plt.grid(axis = "y")
plt.grid(color = "black", linestyle = "--", linewidth = 0.9)


# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 15, 30]

plt.plot(x, y)

plt.title("Title", fontsize=30,color = "b")           # Set title font size to 16 points
plt.xlabel("X Label", fontsize=30,color = "r")        # Set x-axis label font size to 12 points
plt.ylabel("Y Label", fontsize=30,color = "r")        # Set y-axis label font size to 12 points
plt.xticks(fontsize=15)                   # Set tick label font size to 10 points for x-axis
plt.yticks(fontsize=15)                   # Set tick label font size to 10 points for y-axis
plt.legend(["Data"], fontsize="large") # Set legend font size to medium

plt.grid()

plt.show()

# %% [markdown]
# # matplotlib subplot

# %%
df = pd.read_csv("D:\\excel data\\studentdata.csv")
df
# Out:
#   StudentName  Marks
# 0      Keshvi     25
# 1       kayra     10
# 2       pooja     35
# 3     abhiman     40
# 4        mona     45

# %%
plt.pie(df['Marks'],labels = df['StudentName'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints = np.array([5,10,15,20,25])
ypoints = np.array([20,30,40,50,60])

plt.subplot(1,3,1)
plt.plot(x,y)



plt.show()

# %%
x = np.array([0,1,2,3,4,5])
y = np.array([6,7,8,9,10,11])


plt.subplot(1,3,1)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # scatter plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])


plt.scatter(x,y)

plt.xlabel("no of data")
plt.ylabel("data")

plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])

plt.xlabel("No of Data")
plt.ylabel("Data")

plt.scatter(x, y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])

plt.scatter(x, y)
plt.grid()

# Adding labels to the axes
#plt.xlabel("No of Data")
#plt.ylabel("Data")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)
plt.grid()

plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 15, 30]

plt.scatter(x, y)  # Adjust alpha to control point transparency

#plt.grid()

#plt.xlabel("X Values")
plt.xlabel("xlable")
plt.ylabel("ylable")
#plt.ylabel("Y Values")
#plt.title("Scatter Plot with Transparency")

plt.show()

# %%
df = pd.read_csv("D:\\excel data\\studentdata.csv")
df
# Out:
#   StudentName  Marks
# 0      Keshvi     25
# 1       kayra     10
# 2       pooja     35
# 3     abhiman     40
# 4        mona     45

# %%
plt.bar(df["Marks"],df["StudentName"])
plt.show()

# %%
plt.scatter(df["Marks"],df["StudentName"])
plt.show()

# %%
plt.pie(df["Marks"],labels = df["StudentName"])
plt.show()

# %%
x = np.random.normal(1,20,100)
plt.hist(x)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def float_to_time(x):
    return str(int(x)) + ":" + str(int(x%1 * 60)).zfill(2) + ":" + str(int(x*60 % 1 * 60)).zfill(2)

def day_stock_data():
    #NYSE is open from 9:30 to 4:00
    time = 9.5
    price = 100
    results = [(float_to_time(time), price)]
    while time < 16:
        elapsed = np.random.exponential(.001)
        time += elapsed
        if time > 16:
            break
        price_diff = np.random.uniform(.999, 1.001)
        price *= price_diff
        results.append((float_to_time(time), price))
    
    
    df = pd.DataFrame(results, columns = ['time','price'])
    df.time = pd.to_datetime(df.time)
    return df

stock_data = day_stock_data()
print(stock_data)


#Don't read me unless you get stuck!
def plot_candlestick(agg):
    
    
    """
    agg is a DataFrame which has a DatetimeIndex and five columns: ["open","high","low","close","color"]
   """
    agg = stock_data.groupby(stock_data.time.dt.hour).agg(
    open=pd.NamedAgg(column='price', aggfunc='first'),
    high=pd.NamedAgg(column='price', aggfunc='max'),
    low=pd.NamedAgg(column='price', aggfunc='min'),
    close=pd.NamedAgg(column='price', aggfunc='last'),
    color=pd.NamedAgg(column='price', aggfunc=lambda x: 'g' if x.iloc[0] <= x.iloc[-1] else 'r')
    )
plot_candlestick(agg)

fig, ax = plt.subplots()
for time in agg.index:
    ax.plot([time.hour] * 2, agg.loc[time, ["high","low"]].values, color = "black")
    ax.plot([time.hour] * 2, agg.loc[time, ["open","close"]].values, color = agg.loc[time, "color"], linewidth = 10)


ax.set_xlim((8,16))
ax.set_ylabel("Price")
ax.set_xlabel("Hour")
ax.set_title("OHLC of Stock Value During Trading Day")


plt.show()
# Out:
#                     time       price
# 0    2023-08-23 09:30:00  100.000000
# 1    2023-08-23 09:30:00   99.987698
# 2    2023-08-23 09:30:01  100.043727
# 3    2023-08-23 09:30:06   99.967769
# 4    2023-08-23 09:30:06  100.026475
# ...                  ...         ...
# 6616 2023-08-23 15:59:43   93.384388
# 6617 2023-08-23 15:59:49   93.312177
# 6618 2023-08-23 15:59:54   93.276373
# 6619 2023-08-23 15:59:54   93.327333
# 6620 2023-08-23 15:59:59   93.276359
#
# [6621 rows x 2 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 41>()
#      31     """
#      32     agg is a DataFrame which has a DatetimeIndex and five columns: ["open","high","low","close","color"]
#      33    """
#      34     agg = stock_data.groupby(stock_data.time.dt.hour).agg(
#      35     open=pd.NamedAgg(column='price', aggfunc='first'),
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the style
plt.style.use('ggplot')

# Create a DataFrame
df = pd.DataFrame({"xs": [1, 5, 2, 8, 1], "ys": [4, 2, 1, 9, 6]})

# Create a scatter plot with black X markers
df.plot(kind='scatter', x='xs', y='ys', marker='x', color='black')

# Add labels and title
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Scatter Plot with Custom Markers")

# Show the plot
plt.show()
