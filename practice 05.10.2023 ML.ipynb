# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("D:\\excel data\\mobiles.csv")

# %%
df
# Out:
#      Unnamed: 0    Brand                                              Title  \
# 0             0    APPLE                     APPLE iPhone 13 (Pink, 128 GB)
# 1             1     POCO                      POCO C51 (Power Black, 64 GB)
# 2             2  OnePlus     OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3             3   realme                realme 11x 5G (Purple Dawn, 128 GB)
# 4             4   realme             realme 11x 5G (Midnight Black, 128 GB)
# ..          ...      ...                                                ...
# 979         979    APPLE                    APPLE iPhone 12 (White, 128 GB)
# 980         980    Tecno                 Tecno Pova 3 (Tech Silver, 128 GB)
# 981         981    REDMI           REDMI Note 11 SE (Thunder Purple, 64 GB)
# 982         982     vivo                    vivo Y16 (Steller Black, 64 GB)
# 983         983    Tecno  Tecno Camon 19 Pro Multi-Colour Changing Back-...
#
#                                         Model Name   Model Number  Price  \
# 0                                        iPhone 13      MLPH3HN/A  52499
# 1                                              C51      MZB0E6DIN   6499
# 2                                Nord CE 2 Lite 5G    CPH2381/CVD  17196
# 3                                           11x 5G        RMX3785  15999
# 4                                           11x 5G        RMX3785  14999
# ..                                             ...            ...    ...
# 979                                      iPhone 12      MGJC3HN/A  51999
# 980                                         Pova 3            LF7  13999
# 981                                     Note 11 SE      MZB0CK8IN  12890
# 982                                            Y16  V2204 | V2214  10699
# 983  Camon 19 Pro Multi-Colour Changing Back-Panel           CI8n  14940
#
#      Rating  No_of_Ratings  No_of_Reviews  \
# 0       4.7       259109.0        12745.0
# 1       4.1        78642.0         4449.0
# 2       4.4       110949.0         7728.0
# 3       4.3         2633.0          220.0
# 4       4.4        13807.0          988.0
# ..      ...            ...            ...
# 979     4.6       190693.0        12872.0
# 980     4.1          522.0           24.0
# 981     4.3        47843.0         2894.0
# 982     4.2         2908.0          152.0
# 983     4.1          145.0           13.0
#
#                                             In The Box  ...  \
# 0      iPhone, USB-C to Lightning Cable, Documentation  ...
# 1    Handset, 10W Adapter, USB Cable, Sim Eject Too...  ...
# 2    Phone,SIM Tray Ejector, Adapter, Phone Case, U...  ...
# 3    Handset, Adapter, USB Cable, Important Info Bo...  ...
# 4    Handset, Adapter, USB Cable, Important Info Bo...  ...
# ..                                                 ...  ...
# 979    iPhone, USB-C to Lightning Cable, Documentation  ...
# 980  Handset, USB Cable, Charger, User Guide, SIM E...  ...
# 981  Handset, USB Type-C Cable, Sim Eject Tool, Pro...  ...
# 982  Handset, Documentation, Type-C to USB Cable, U...  ...
# 983  Handset, USB Cable, Charger, User Guide, SIM E...  ...
#
#                                                Sensors        Browser  \
# 0    Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 1                    Accelerometer, Fingerprint Sensor  Google Chrome
# 2                    Accelerometer, Fingerprint Sensor  Google Chrome
# 3    Magnetic Induction Sensor, Light Sensor, Proxi...            NaN
# 4    Magnetic Induction Sensor, Light Sensor, Proxi...            NaN
# ..                                                 ...            ...
# 979  Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 980  Fingerprint Sensor (side-mounted), G-Sensor, A...  Google Chrome
# 981  Accelerometer, Fingerprint Sensor, Gyro Sensor...  Google Chrome
# 982  Accelerometer, Ambient Light Sensor, Proximity...  Google Chrome
# 983  G-Sensor, Ambient Light and Distance Sensor, F...  Google Chrome
#
#                                         Other Features  \
# 0    Splash, Water and Dust Resistant IP68 Rated (M...
# 1    Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 2    Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 3    COG Sealing Process, In-Cell Touch Panel Techn...
# 4    COG Sealing Process, In-Cell Touch Panel Techn...
# ..                                                 ...
# 979  Splash, Water and Dust Resistant (Rated IP68 (...
# 980  Memory Fusion 2.1, 4D Vibration & Z-axis Linea...
# 981                                                NaN
# 982       10W Fast Charging, Handset Material: Plastic
# 983  13GB RAM (8GB LPDDR4x RAM + Up to 5GB Memory F...
#
#                                             GPS Type  \
# 0    Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 1                         GPS, AGPS, GLONASS, BEIDOU
# 2                         GPS, AGPS, GLONASS, BEIDOU
# 3                GPS, AGPS, BEIDOU, GALILEO, GLONASS
# 4                GPS, AGPS, BEIDOU, GALILEO, GLONASS
# ..                                               ...
# 979  Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 980                                              NaN
# 981                       GPS, AGPS, GLONASS, BEIDOU
# 982                    GPS, BEIDOU, GLONASS, GALILEO
# 983                                              NaN
#
#                                          Video Formats Battery Capacity  \
# 0    HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         3240 mAh
# 1                                                  NaN         5000 mAh
# 2                                                  NaN         5000 mAh
# 3    MP4, 3GP, ASF, AVI, FLV, M2TS, MKV, MPG, TS, W...         5000 mAh
# 4    MP4, 3GP, ASF, AVI, FLV, M2TS, MKV, MPG, TS, W...         5000 mAh
# ..                                                 ...              ...
# 979  HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         4500 mAh
# 980                                                NaN         7000 mAh
# 981                                                NaN         5000 mAh
# 982                        MP4, 3GP, AVI, TS, MKV, FLV         5000 mAh
# 983                        MP4, 3GP, AVI, TS, MKV, FLV         5000 mAh
#
#         Width     Height    Depth   Weight
# 0     71.5 mm   146.7 mm  7.65 mm    173 g
# 1    76.75 mm   164.9 mm  9.09 mm    192 g
# 2    76.75 mm   164.9 mm  9.09 mm    192 g
# 3       76 mm   165.7 mm  7.89 mm    190 g
# 4       76 mm   165.7 mm  7.89 mm    190 g
# ..        ...        ...      ...      ...
# 979   71.5 mm   146.7 mm   7.4 mm    162 g
# 980  78.46 mm   173.1 mm  9.44 mm      NaN
# 981   74.5 mm  160.46 mm  8.29 mm  178.8 g
# 982  75.55 mm  163.95 mm  8.19 mm    183 g
# 983  74.55 mm  166.79 mm  8.58 mm      NaN
#
# [984 rows x 74 columns]

# %%
df.drop(["Unnamed: 0"],axis = 1)
# Out:
#        Brand                                              Title  \
# 0      APPLE                     APPLE iPhone 13 (Pink, 128 GB)
# 1       POCO                      POCO C51 (Power Black, 64 GB)
# 2    OnePlus     OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3     realme                realme 11x 5G (Purple Dawn, 128 GB)
# 4     realme             realme 11x 5G (Midnight Black, 128 GB)
# ..       ...                                                ...
# 979    APPLE                    APPLE iPhone 12 (White, 128 GB)
# 980    Tecno                 Tecno Pova 3 (Tech Silver, 128 GB)
# 981    REDMI           REDMI Note 11 SE (Thunder Purple, 64 GB)
# 982     vivo                    vivo Y16 (Steller Black, 64 GB)
# 983    Tecno  Tecno Camon 19 Pro Multi-Colour Changing Back-...
#
#                                         Model Name   Model Number  Price  \
# 0                                        iPhone 13      MLPH3HN/A  52499
# 1                                              C51      MZB0E6DIN   6499
# 2                                Nord CE 2 Lite 5G    CPH2381/CVD  17196
# 3                                           11x 5G        RMX3785  15999
# 4                                           11x 5G        RMX3785  14999
# ..                                             ...            ...    ...
# 979                                      iPhone 12      MGJC3HN/A  51999
# 980                                         Pova 3            LF7  13999
# 981                                     Note 11 SE      MZB0CK8IN  12890
# 982                                            Y16  V2204 | V2214  10699
# 983  Camon 19 Pro Multi-Colour Changing Back-Panel           CI8n  14940
#
#      Rating  No_of_Ratings  No_of_Reviews  \
# 0       4.7       259109.0        12745.0
# 1       4.1        78642.0         4449.0
# 2       4.4       110949.0         7728.0
# 3       4.3         2633.0          220.0
# 4       4.4        13807.0          988.0
# ..      ...            ...            ...
# 979     4.6       190693.0        12872.0
# 980     4.1          522.0           24.0
# 981     4.3        47843.0         2894.0
# 982     4.2         2908.0          152.0
# 983     4.1          145.0           13.0
#
#                                             In The Box           Color  ...  \
# 0      iPhone, USB-C to Lightning Cable, Documentation            Pink  ...
# 1    Handset, 10W Adapter, USB Cable, Sim Eject Too...     Power Black  ...
# 2    Phone,SIM Tray Ejector, Adapter, Phone Case, U...      Black Dusk  ...
# 3    Handset, Adapter, USB Cable, Important Info Bo...     Purple Dawn  ...
# 4    Handset, Adapter, USB Cable, Important Info Bo...  Midnight Black  ...
# ..                                                 ...             ...  ...
# 979    iPhone, USB-C to Lightning Cable, Documentation           White  ...
# 980  Handset, USB Cable, Charger, User Guide, SIM E...     Tech Silver  ...
# 981  Handset, USB Type-C Cable, Sim Eject Tool, Pro...  Thunder Purple  ...
# 982  Handset, Documentation, Type-C to USB Cable, U...   Steller Black  ...
# 983  Handset, USB Cable, Charger, User Guide, SIM E...        Mondrian  ...
#
#                                                Sensors        Browser  \
# 0    Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 1                    Accelerometer, Fingerprint Sensor  Google Chrome
# 2                    Accelerometer, Fingerprint Sensor  Google Chrome
# 3    Magnetic Induction Sensor, Light Sensor, Proxi...            NaN
# 4    Magnetic Induction Sensor, Light Sensor, Proxi...            NaN
# ..                                                 ...            ...
# 979  Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 980  Fingerprint Sensor (side-mounted), G-Sensor, A...  Google Chrome
# 981  Accelerometer, Fingerprint Sensor, Gyro Sensor...  Google Chrome
# 982  Accelerometer, Ambient Light Sensor, Proximity...  Google Chrome
# 983  G-Sensor, Ambient Light and Distance Sensor, F...  Google Chrome
#
#                                         Other Features  \
# 0    Splash, Water and Dust Resistant IP68 Rated (M...
# 1    Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 2    Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 3    COG Sealing Process, In-Cell Touch Panel Techn...
# 4    COG Sealing Process, In-Cell Touch Panel Techn...
# ..                                                 ...
# 979  Splash, Water and Dust Resistant (Rated IP68 (...
# 980  Memory Fusion 2.1, 4D Vibration & Z-axis Linea...
# 981                                                NaN
# 982       10W Fast Charging, Handset Material: Plastic
# 983  13GB RAM (8GB LPDDR4x RAM + Up to 5GB Memory F...
#
#                                             GPS Type  \
# 0    Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 1                         GPS, AGPS, GLONASS, BEIDOU
# 2                         GPS, AGPS, GLONASS, BEIDOU
# 3                GPS, AGPS, BEIDOU, GALILEO, GLONASS
# 4                GPS, AGPS, BEIDOU, GALILEO, GLONASS
# ..                                               ...
# 979  Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 980                                              NaN
# 981                       GPS, AGPS, GLONASS, BEIDOU
# 982                    GPS, BEIDOU, GLONASS, GALILEO
# 983                                              NaN
#
#                                          Video Formats Battery Capacity  \
# 0    HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         3240 mAh
# 1                                                  NaN         5000 mAh
# 2                                                  NaN         5000 mAh
# 3    MP4, 3GP, ASF, AVI, FLV, M2TS, MKV, MPG, TS, W...         5000 mAh
# 4    MP4, 3GP, ASF, AVI, FLV, M2TS, MKV, MPG, TS, W...         5000 mAh
# ..                                                 ...              ...
# 979  HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         4500 mAh
# 980                                                NaN         7000 mAh
# 981                                                NaN         5000 mAh
# 982                        MP4, 3GP, AVI, TS, MKV, FLV         5000 mAh
# 983                        MP4, 3GP, AVI, TS, MKV, FLV         5000 mAh
#
#         Width     Height    Depth   Weight
# 0     71.5 mm   146.7 mm  7.65 mm    173 g
# 1    76.75 mm   164.9 mm  9.09 mm    192 g
# 2    76.75 mm   164.9 mm  9.09 mm    192 g
# 3       76 mm   165.7 mm  7.89 mm    190 g
# 4       76 mm   165.7 mm  7.89 mm    190 g
# ..        ...        ...      ...      ...
# 979   71.5 mm   146.7 mm   7.4 mm    162 g
# 980  78.46 mm   173.1 mm  9.44 mm      NaN
# 981   74.5 mm  160.46 mm  8.29 mm  178.8 g
# 982  75.55 mm  163.95 mm  8.19 mm    183 g
# 983  74.55 mm  166.79 mm  8.58 mm      NaN
#
# [984 rows x 73 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Brand                 0
# Title                 0
# Model Name            0
# Model Number          5
#                    ...
# Battery Capacity      0
# Width               104
# Height              109
# Depth               105
# Weight               44
# Length: 74, dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Brand               0
# Title               0
# Model Name          0
# Model Number        0
#                    ..
# Battery Capacity    0
# Width               0
# Height              0
# Depth               0
# Weight              0
# Length: 74, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 965
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  16 non-null     int64
#  1   Brand                       16 non-null     object
#  2   Title                       16 non-null     object
#  3   Model Name                  16 non-null     object
#  4   Model Number                16 non-null     object
#  5   Price                       16 non-null     int64
#  6   Rating                      16 non-null     float64
#  7   No_of_Ratings               16 non-null     float64
#  8   No_of_Reviews               16 non-null     float64
#  9   In The Box                  16 non-null     object
#  10  Color                       16 non-null     object
#  11  Browse Type                 16 non-null     object
#  12  SIM Type                    16 non-null     object
#  13  Hybrid Sim Slot             16 non-null     object
#  14  Touchscreen                 16 non-null     object
#  15  OTG Compatible              16 non-null     object
#  16  Quick Charging              16 non-null     object
#  17  Sound Enhancements          16 non-null     object
#  18  Display_size_cm             16 non-null     float64
#  19  Display_size_inches         16 non-null     float64
#  20  Resolution                  16 non-null     object
#  21  Resolution Type             16 non-null     object
#  22  Display Type                16 non-null     object
#  23  Other Display Features      16 non-null     object
#  24  Operating System            16 non-null     object
#  25  Processor Type              16 non-null     object
#  26  Processor Core              16 non-null     object
#  27  Operating Frequency         16 non-null     object
#  28  Internal Storage            16 non-null     object
#  29  Primary Camera Available    16 non-null     object
#  30  Primary Camera              16 non-null     object
#  31  Primary Camera Features     16 non-null     object
#  32  Secondary Camera Available  16 non-null     object
#  33  Secondary Camera            16 non-null     object
#  34  Secondary Camera Features   16 non-null     object
#  35  Flash                       16 non-null     object
#  36  HD Recording                16 non-null     object
#  37  Full HD Recording           16 non-null     object
#  38  Video Recording             16 non-null     object
#  39  Video Recording Resolution  16 non-null     object
#  40  Digital Zoom                16 non-null     object
#  41  Frame Rate                  16 non-null     object
#  42  Dual Camera Lens            16 non-null     object
#  43  Call Wait/Hold              16 non-null     object
#  44  Network Type                16 non-null     object
#  45  Supported Networks          16 non-null     object
#  46  Internet Connectivity       16 non-null     object
#  47  3G                          16 non-null     object
#  48  Pre-installed Browser       16 non-null     object
#  49  Bluetooth Support           16 non-null     object
#  50  Bluetooth Version           16 non-null     object
#  51  Wi-Fi                       16 non-null     object
#  52  Wi-Fi Version               16 non-null     object
#  53  Wi-Fi Hotspot               16 non-null     object
#  54  NFC                         16 non-null     object
#  55  EDGE                        16 non-null     object
#  56  Map Support                 16 non-null     object
#  57  GPS Support                 16 non-null     object
#  58  Smartphone                  16 non-null     object
#  59  SIM Size                    16 non-null     object
#  60  Mobile Tracker              16 non-null     object
#  61  Removable Battery           16 non-null     object
#  62  SMS                         16 non-null     object
#  63  Graphics PPI                16 non-null     object
#  64  Sensors                     16 non-null     object
#  65  Browser                     16 non-null     object
#  66  Other Features              16 non-null     object
#  67  GPS Type                    16 non-null     object
#  68  Video Formats               16 non-null     object
#  69  Battery Capacity            16 non-null     object
#  70  Width                       16 non-null     object
#  71  Height                      16 non-null     object
#  72  Depth                       16 non-null     object
#  73  Weight                      16 non-null     object
# dtypes: float64(5), int64(2), object(67)
# memory usage: 9.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0          Price     Rating  No_of_Ratings  No_of_Reviews  \
# count   16.000000      16.000000  16.000000      16.000000      16.000000
# mean   363.187500   73030.250000   4.687500  178658.937500    8808.187500
# std    314.534835   26061.126063   0.034157  123240.175036    6030.763934
# min      0.000000   52499.000000   4.600000    1494.000000     122.000000
# 25%    112.500000   52499.000000   4.700000    1931.000000     185.000000
# 50%    230.500000   61499.000000   4.700000  259109.000000   12745.000000
# 75%    625.250000   99999.000000   4.700000  259109.000000   12745.000000
# max    965.000000  125999.000000   4.700000  259109.000000   12745.000000
#
#        Display_size_cm  Display_size_inches
# count        16.000000            16.000000
# mean         15.681250             6.175000
# std           0.522594             0.204939
# min          15.490000             6.100000
# 25%          15.490000             6.100000
# 50%          15.490000             6.100000
# 75%          15.490000             6.100000
# max          17.020000             6.700000

# %%
df.drop(["Unnamed: 0"],axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['Brand', 'Title', 'Model Name', 'Model Number', 'Price', 'Rating',
#        'No_of_Ratings', 'No_of_Reviews', 'In The Box', 'Color', 'Browse Type',
#        'SIM Type', 'Hybrid Sim Slot', 'Touchscreen', 'OTG Compatible',
#        'Quick Charging', 'Sound Enhancements', 'Display_size_cm',
#        'Display_size_inches', 'Resolution', 'Resolution Type', 'Display Type',
#        'Other Display Features', 'Operating System', 'Processor Type',
#        'Processor Core', 'Operating Frequency', 'Internal Storage',
#        'Primary Camera Available', 'Primary Camera', 'Primary Camera Features',
#        'Secondary Camera Available', 'Secondary Camera',
#        'Secondary Camera Features', 'Flash', 'HD Recording',
#        'Full HD Recording', 'Video Recording', 'Video Recording Resolution',
#        'Digital Zoom', 'Frame Rate', 'Dual Camera Lens', 'Call Wait/Hold',
#        'Network Type', 'Supported Networks', 'Internet Connectivity', '3G',
#        'Pre-installed Browser', 'Bluetooth Support', 'Bluetooth Version',
#        'Wi-Fi', 'Wi-Fi Version', 'Wi-Fi Hotspot', 'NFC', 'EDGE', 'Map Support',
#        'GPS Support', 'Smartphone', 'SIM Size', 'Mobile Tracker',
#        'Removable Battery', 'SMS', 'Graphics PPI', 'Sensors', 'Browser',
#        'Other Features', 'GPS Type', 'Video Formats', 'Battery Capacity',
#        'Width', 'Height', 'Depth', 'Weight'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Price     Rating  No_of_Ratings  No_of_Reviews  \
# count      16.000000  16.000000      16.000000      16.000000
# mean    73030.250000   4.687500  178658.937500    8808.187500
# std     26061.126063   0.034157  123240.175036    6030.763934
# min     52499.000000   4.600000    1494.000000     122.000000
# 25%     52499.000000   4.700000    1931.000000     185.000000
# 50%     61499.000000   4.700000  259109.000000   12745.000000
# 75%     99999.000000   4.700000  259109.000000   12745.000000
# max    125999.000000   4.700000  259109.000000   12745.000000
#
#        Display_size_cm  Display_size_inches
# count        16.000000            16.000000
# mean         15.681250             6.175000
# std           0.522594             0.204939
# min          15.490000             6.100000
# 25%          15.490000             6.100000
# 50%          15.490000             6.100000
# 75%          15.490000             6.100000
# max          17.020000             6.700000

# %%
df["Brand"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df["Brand"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Brand'

# %%
import math

abs(math.sqrt(36))
# Out:
# 6.0
