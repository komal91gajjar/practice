# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\\excel data\\mobiles.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    Brand                                           Title  \
# 0           0    APPLE                  APPLE iPhone 13 (Pink, 128 GB)
# 1           1     POCO                   POCO C51 (Power Black, 64 GB)
# 2           2  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3           3   realme             realme 11x 5G (Purple Dawn, 128 GB)
# 4           4   realme          realme 11x 5G (Midnight Black, 128 GB)
#
#           Model Name Model Number  Price  Rating  No_of_Ratings  \
# 0          iPhone 13    MLPH3HN/A  52499     4.7       259109.0
# 1                C51    MZB0E6DIN   6499     4.1        78642.0
# 2  Nord CE 2 Lite 5G  CPH2381/CVD  17196     4.4       110949.0
# 3             11x 5G      RMX3785  15999     4.3         2633.0
# 4             11x 5G      RMX3785  14999     4.4        13807.0
#
#    No_of_Reviews                                         In The Box  ...  \
# 0        12745.0    iPhone, USB-C to Lightning Cable, Documentation  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  984 non-null    int64
#  1   Brand                       984 non-null    object
#  2   Title                       984 non-null    object
#  3   Model Name                  984 non-null    object
#  4   Model Number                979 non-null    object
#  5   Price                       984 non-null    int64
#  6   Rating                      984 non-null    float64
#  7   No_of_Ratings               960 non-null    float64
#  8   No_of_Reviews               960 non-null    float64
#  9   In The Box                  983 non-null    object
#  10  Color                       984 non-null    object
#  11  Browse Type                 984 non-null    object
#  12  SIM Type                    984 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0          Price      Rating  No_of_Ratings  No_of_Reviews  \
# count  984.000000     984.000000  984.000000     960.000000     960.000000
# mean   491.500000   19280.004065    4.165041   24208.828125    1694.629167
# std    284.200633   26030.388513    0.281070   51070.997360    3361.259032
# min      0.000000     597.000000    2.900000       6.000000       0.000000
# 25%    245.750000    2098.000000    4.000000    1008.000000      84.000000
# 50%    491.500000   11634.500000    4.200000    4995.000000     452.500000
# 75%    737.250000   21999.000000    4.300000   19762.000000    1696.000000
# max    983.000000  199900.000000    5.000000  485853.000000   34861.000000
#
#        Display_size_cm  Display_size_inches
# count       984.000000           984.000000
# mean         13.502317             5.315948
# std           5.448735             2.145569
# min           1.680000             0.660000
# 25%           6.475000             2.550000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Brand                 0
# Title                 0
# Model Name            0
# Model Number          5
#                    ...
# Battery Capacity      0
# Width               104
# Height              109
# Depth               105
# Weight               44
# Length: 74, dtype: int64

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Brand', 'Title', 'Model Name', 'Model Number', 'Price', 'Rating',
#        'No_of_Ratings', 'No_of_Reviews', 'In The Box', 'Color', 'Browse Type',
#        'SIM Type', 'Hybrid Sim Slot', 'Touchscreen', 'OTG Compatible',
#        'Quick Charging', 'Sound Enhancements', 'Display_size_cm',
#        'Display_size_inches', 'Resolution', 'Resolution Type', 'Display Type',
#        'Other Display Features', 'Operating System', 'Processor Type',
#        'Processor Core', 'Operating Frequency', 'Internal Storage',
#        'Primary Camera Available', 'Primary Camera', 'Primary Camera Features',
#        'Secondary Camera Available', 'Secondary Camera',
#        'Secondary Camera Features', 'Flash', 'HD Recording',
#        'Full HD Recording', 'Video Recording', 'Video Recording Resolution',
#        'Digital Zoom', 'Frame Rate', 'Dual Camera Lens', 'Call Wait/Hold',
#        'Network Type', 'Supported Networks', 'Internet Connectivity', '3G',
# ...

# %%
df
# Out:
#        Brand                                              Title  \
# 0      APPLE                     APPLE iPhone 13 (Pink, 128 GB)
# 1       POCO                      POCO C51 (Power Black, 64 GB)
# 2    OnePlus     OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3     realme                realme 11x 5G (Purple Dawn, 128 GB)
# 4     realme             realme 11x 5G (Midnight Black, 128 GB)
# ..       ...                                                ...
# 979    APPLE                    APPLE iPhone 12 (White, 128 GB)
# 980    Tecno                 Tecno Pova 3 (Tech Silver, 128 GB)
# 981    REDMI           REDMI Note 11 SE (Thunder Purple, 64 GB)
# 982     vivo                    vivo Y16 (Steller Black, 64 GB)
# 983    Tecno  Tecno Camon 19 Pro Multi-Colour Changing Back-...
#
#                                         Model Name   Model Number  Price  \
# 0                                        iPhone 13      MLPH3HN/A  52499
# ...

# %%
df["Brand"].value_counts()
# Out:
# Brand
# REDMI        97
# APPLE        88
# realme       88
# SAMSUNG      80
# Infinix      69
# POCO         57
# Kechaoda     50
# MOTOROLA     49
# vivo         48
# itel         48
# OnePlus      35
# Nokia        35
# Tecno        34
# LAVA         27
# Micromax     23
# OPPO         22
# KARBONN      21
# Snexian      15
# I            14
# IQOO         10
# Good          8
# MarQ          6
# SAREGAMA      6
# Google        6
# HOTLINE       5
# GFive         5
# DIZO          5
# Cellecor      5
# MTR           4
# Mi            4
# Nothing       4
# IAIR          4
# Xiaomi        4
# UiSmart       3
# Eunity        2
# Energizer     1
# Peace         1
# Itel          1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Brand                 0
# Title                 0
# Model Name            0
# Model Number          5
# Price                 0
#                    ...
# Battery Capacity      0
# Width               104
# Height              109
# Depth               105
# Weight               44
# Length: 73, dtype: int64

# %%
df.dropna(subset= ["Model Number"],inplace=True)

# df.dropna(subset=['column_name'], inplace=True)

# %%
df.dropna(subset=["Width","Height","Depth","Weight"],inplace=True)

# %%
df.columns
# Out:
# Index(['Brand', 'Title', 'Model Name', 'Model Number', 'Price', 'Rating',
#        'No_of_Ratings', 'No_of_Reviews', 'In The Box', 'Color', 'Browse Type',
#        'SIM Type', 'Hybrid Sim Slot', 'Touchscreen', 'OTG Compatible',
#        'Quick Charging', 'Sound Enhancements', 'Display_size_cm',
#        'Display_size_inches', 'Resolution', 'Resolution Type', 'Display Type',
#        'Other Display Features', 'Operating System', 'Processor Type',
#        'Processor Core', 'Operating Frequency', 'Internal Storage',
#        'Primary Camera Available', 'Primary Camera', 'Primary Camera Features',
#        'Secondary Camera Available', 'Secondary Camera',
#        'Secondary Camera Features', 'Flash', 'HD Recording',
#        'Full HD Recording', 'Video Recording', 'Video Recording Resolution',
#        'Digital Zoom', 'Frame Rate', 'Dual Camera Lens', 'Call Wait/Hold',
#        'Network Type', 'Supported Networks', 'Internet Connectivity', '3G',
# ...

# %%
df.isnull().sum()
# Out:
# Brand               0
# Title               0
# Model Name          0
# Model Number        0
# Price               0
#                    ..
# Battery Capacity    0
# Width               0
# Height              0
# Depth               0
# Weight              0
# Length: 73, dtype: int64

# %%
df["Brand"].value_counts()
# Out:
# Brand
# APPLE        88
# REDMI        87
# realme       85
# SAMSUNG      73
# Infinix      64
# POCO         57
# MOTOROLA     49
# vivo         48
# itel         38
# Kechaoda     37
# OnePlus      27
# Micromax     20
# LAVA         20
# OPPO         18
# Nokia        16
# KARBONN      14
# Tecno        12
# Snexian      10
# IQOO          7
# Google        6
# MarQ          5
# GFive         5
# DIZO          5
# SAREGAMA      4
# Mi            4
# Nothing       4
# Xiaomi        4
# Good          4
# HOTLINE       3
# IAIR          3
# I             3
# Cellecor      2
# Energizer     1
# Eunity        1
# Peace         1
# UiSmart       1
# Itel          1
# MTR           1
# Name: count, dtype: int64

# %%
plt.plot(df["Brand"])

# %%
# %matplotlib inline

# %%
sns.barplot(x = df["Brand"],y = df["Price"])
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
print(sorted(df["Brand"], reverse=True)[:5])
# Out:
# ['vivo', 'vivo', 'vivo', 'vivo', 'vivo']

# %%
#Top 10 rows
top_five_brand = (df["Brand"])[:10]

# %%
top_five_brand
# Out:
# 0       APPLE
# 1        POCO
# 2     OnePlus
# 3      realme
# 4      realme
# 5        POCO
# 6       APPLE
# 7        POCO
# 8        vivo
# 9    MOTOROLA
# Name: Brand, dtype: object

# %%
top_seling_price = (df["Price"])[:10]

# %%
top_seling_price
# Out:
# 0    52499
# 1     6499
# 2    17196
# 3    15999
# 4    14999
# 5     8499
# 6    52499
# 7     6499
# 8    12999
# 9    19999
# Name: Price, dtype: int64

# %%
sns.barplot(x = top_five_brand, y = top_seling_price)
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
# c = ['red', 'yellow', 'black', 'blue', 'orange']
plt.bar(top_five_brand,top_seling_price)
plt.xlabel("Top_five_brand")
plt.ylabel("Top_seling_price")
plt.title("Top 10 brands of mobiles")
plt.show()

# %%
top_10_brand = df["Brand"].value_counts().head(10)

# %%
top_10_brand
# Out:
# Brand
# APPLE       88
# REDMI       87
# realme      85
# SAMSUNG     73
# Infinix     64
# POCO        57
# MOTOROLA    49
# vivo        48
# itel        38
# Kechaoda    37
# Name: count, dtype: int64

# %%
top_10_selling_price = df["Price"].value_counts().head(10)

# %%
top_10_selling_price
# Out:
# Price
# 10999    24
# 12999    20
# 11999    19
# 16999    18
# 18999    18
# 15999    17
# 14999    17
# 29999    15
# 9999     15
# 19999    14
# Name: count, dtype: int64

# %%
df["Brand"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Brand'>

# %%
plt.pie(top_10_brand)
plt.plot()
# Out:
# []

# %%
c = ['red', 'yellow', 'black', 'blue', 'orange','red', 'yellow', 'black', 'blue', 'orange']
plt.bar(top_10_brand, top_10_selling_price)
plt.xlabel("top_10_brand")
plt.ylabel("top_10_selling_price")
plt.show()

# %%
df_ipl = pd.read_csv("D:\\excel data\\ipl-matches.csv")

# %%
df_ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  29/05/2022     2022        Final
# 1    1312199   Ahmedabad  27/05/2022     2022  Qualifier 2
# 2    1312198     Kolkata  25/05/2022     2022   Eliminator
# 3    1312197     Kolkata  24/05/2022     2022  Qualifier 1
# 4    1304116      Mumbai  22/05/2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20/04/2008  2007/08            4
# 946   335985      Mumbai  20/04/2008  2007/08            5
# 947   335984       Delhi  19/04/2008  2007/08            3
# 948   335983  Chandigarh  19/04/2008  2007/08            2
# 949   335982   Bangalore  18/04/2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df_ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  29/05/2022   2022        Final
# 1  1312199  Ahmedabad  27/05/2022   2022  Qualifier 2
# 2  1312198    Kolkata  25/05/2022   2022   Eliminator
# 3  1312197    Kolkata  24/05/2022   2022  Qualifier 1
# 4  1304116     Mumbai  22/05/2022   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df_ipl.duplicated().sum()
# Out:
# 0

# %%
df_ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df_ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df_ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df_ipl.dropna(subset= ["City","Margin","method"],inplace=True)

# df.dropna(subset=["Width","Height","Depth","Weight"],inplace=True)

# %%
df_ipl.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
# how to fetch single column in DataFrame
df_ipl["Player_of_Match"]
# Out:
# 282             RR Pant
# 296            KL Rahul
# 308           SV Samson
# 316     NM Coulter-Nile
# 383             V Kohli
# 384            AB Dinda
# 389           YK Pathan
# 411            AB Dinda
# 441             V Kohli
# 472           DA Warner
# 520            DW Steyn
# 717            CH Gayle
# 728       Iqbal Abdulla
# 757         BB McCullum
# 860           ML Hayden
# 886            CH Gayle
# 889          DL Vettori
# 908             M Ntini
# 910    DPMD Jayawardene
# Name: Player_of_Match, dtype: object

# %%
# how to fetch multipal column in DataFrame
df_ipl[["Team1","Team2","WinningTeam","Date","City"]]
# Out:
#                            Team1                        Team2  \
# 282             Delhi Daredevils             Rajasthan Royals
# 296        Kolkata Knight Riders              Kings XI Punjab
# 308             Rajasthan Royals             Delhi Daredevils
# 316          Sunrisers Hyderabad        Kolkata Knight Riders
# 383  Royal Challengers Bangalore              Kings XI Punjab
# 384      Rising Pune Supergiants             Delhi Daredevils
# 389        Kolkata Knight Riders      Rising Pune Supergiants
# 411          Sunrisers Hyderabad      Rising Pune Supergiants
# 441          Sunrisers Hyderabad  Royal Challengers Bangalore
# 472          Sunrisers Hyderabad        Kolkata Knight Riders
# 520             Delhi Daredevils          Sunrisers Hyderabad
# 717  Royal Challengers Bangalore        Kolkata Knight Riders
# 728        Kolkata Knight Riders          Chennai Super Kings
# 757         Kochi Tuskers Kerala          Chennai Super Kings
# ...

# %%
df_ipl
# Out:
#           ID           City        Date   Season MatchNumber  \
# 282  1136592          Delhi  02/05/2018     2018          32
# 296  1136578        Kolkata  21/04/2018     2018          18
# 308  1136566         Jaipur  11/04/2018     2018           6
# 316  1082648      Bangalore  17/05/2017     2017  Eliminator
# 383   980999      Bangalore  18/05/2016     2016          50
# 384   980997  Visakhapatnam  17/05/2016     2016          49
# 389   980989        Kolkata  14/05/2016     2016          45
# 411   980943      Hyderabad  26/04/2016     2016          22
# 441   829807      Hyderabad  15/05/2015     2015          52
# 472   829743  Visakhapatnam  22/04/2015     2015          19
# 520   733993          Delhi  10/05/2014     2014          32
# 717   501255      Bangalore  14/05/2011     2011          58
# 728   501245        Kolkata  07/05/2011     2011          48
# 757   501215          Kochi  18/04/2011     2011          18
# ...

# %%
# how to fetch single row in DataFrame

df_ipl.iloc[0]
# Out:
# ID                                                           1136592
# City                                                           Delhi
# Date                                                      02/05/2018
# Season                                                          2018
# MatchNumber                                                       32
# Team1                                               Delhi Daredevils
# Team2                                               Rajasthan Royals
# Venue                                           Arun Jaitley Stadium
# TossWinner                                          Rajasthan Royals
# TossDecision                                                   field
# SuperOver                                                          N
# WinningTeam                                         Delhi Daredevils
# WonBy                                                           Runs
# Margin                                                           4.0
# ...

# %%
# how to fetch multipal row in DataFrame
df_ipl.iloc[0:10]
# Out:
#           ID           City        Date Season MatchNumber  \
# 282  1136592          Delhi  02/05/2018   2018          32
# 296  1136578        Kolkata  21/04/2018   2018          18
# 308  1136566         Jaipur  11/04/2018   2018           6
# 316  1082648      Bangalore  17/05/2017   2017  Eliminator
# 383   980999      Bangalore  18/05/2016   2016          50
# 384   980997  Visakhapatnam  17/05/2016   2016          49
# 389   980989        Kolkata  14/05/2016   2016          45
# 411   980943      Hyderabad  26/04/2016   2016          22
# 441   829807      Hyderabad  15/05/2015   2015          52
# 472   829743  Visakhapatnam  22/04/2015   2015          19
#
#                            Team1                        Team2  \
# 282             Delhi Daredevils             Rajasthan Royals
# 296        Kolkata Knight Riders              Kings XI Punjab
# 308             Rajasthan Royals             Delhi Daredevils
# 316          Sunrisers Hyderabad        Kolkata Knight Riders
# ...

# %%
df_ipl.head(2)
# Out:
#           ID     City        Date  Year MatchNumber                  Team1  \
# 282  1136592    Delhi  02/05/2018  year          32       Delhi Daredevils
# 296  1136578  Kolkata  21/04/2018  year          18  Kolkata Knight Riders
#
#                 Team2                 Venue        TossWinner TossDecision  \
# 282  Rajasthan Royals  Arun Jaitley Stadium  Rajasthan Royals        field
# 296   Kings XI Punjab          Eden Gardens   Kings XI Punjab        field
#
#     SuperOver       WinningTeam    WonBy  Margin method Player_of_Match  \
# 282         N  Delhi Daredevils     Runs     4.0    D/L         RR Pant
# 296         N   Kings XI Punjab  Wickets     9.0    D/L        KL Rahul
#
#                                           Team1Players  \
# 282  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
# 296  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...
#
#                                           Team2Players     Umpire1  \
# ...

# %%
# df_ipl.rename(["Season"] == ["Year"])
df_ipl.rename(columns={"Season":"Year"},inplace=True)

# rankings_pd.rename(columns = {'test':'TEST', 'odi':'ODI',
                            #   't20':'T20'}, inplace = True)

# %%
df_ipl.head(1)
# Out:
#           ID   City        Date  Year MatchNumber             Team1  \
# 282  1136592  Delhi  02/05/2018  year          32  Delhi Daredevils
#
#                 Team2                 Venue        TossWinner TossDecision  \
# 282  Rajasthan Royals  Arun Jaitley Stadium  Rajasthan Royals        field
#
#     SuperOver       WinningTeam WonBy  Margin method Player_of_Match  \
# 282         N  Delhi Daredevils  Runs     4.0    D/L         RR Pant
#
#                                           Team1Players  \
# 282  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
#
#                                           Team2Players    Umpire1    Umpire2
# 282  ['DJM Short', 'JC Buttler', 'SV Samson', 'BA S...  CK Nandan  VK Sharma
