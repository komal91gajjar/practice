# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Admin\Desktop\\st_details.csv")

# %%
df
# Out:
#    iq  cgpa placement
# 0  25   8.4         y
# 1  63   9.5         y
# 2  88   6.8         n
# 3  59   6.7         n

# %%
plt.scatter(df["iq"],df["cgpa"])
plt.xlabel("iq")
plt.ylabel("cgpa")
plt.grid()
plt.show()

# %%
df = pd.read_csv("D:\\excel data\\subwaydata.csv")

# %%
df
# Out:
#        Category                   Item  Calories  Total Fat (g)  \
# 0    Sandwiches            BBQ Chicken       330            4.0
# 1    Sandwiches                BBQ Rib       580           31.0
# 2    Sandwiches       Black Forest Ham       260            4.0
# 3    Sandwiches        Buffalo Chicken       360           12.0
# 4    Sandwiches  Chicken & Bacon Ranch       530           26.0
# ..          ...                    ...       ...            ...
# 181      Drinks    Simply Apple® Juice       160            0.0
# 182      Drinks      vitaminwater® XXX         0            0.0
# 183      Extras                  Bacon        70            6.0
# 184      Extras   Caramel Apple Cookie       210            6.0
# 185      Extras              Pepperoni        80            7.0
#
#      Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                  1.0            0.0                50          860
# ...

# %%
df.isnull().sum()
# Out:
# Category                0
# Item                    0
# Calories                0
# Total Fat (g)           0
# Saturated Fat (g)       0
# Trans Fat (g)           0
# Cholesterol (mg)        0
# Sodium (mg)             0
# Carbs (g)               0
# Dietary Fiber (g)       0
# Sugars (g)              0
# Protein (g)             0
# Weight Watchers Pnts    1
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Category                186
# Item                    186
# Calories                186
# Total Fat (g)           186
# Saturated Fat (g)       186
# Trans Fat (g)           186
# Cholesterol (mg)        186
# Sodium (mg)             186
# Carbs (g)               186
# Dietary Fiber (g)       186
# Sugars (g)              186
# Protein (g)             186
# Weight Watchers Pnts    185
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#        Category                   Item  Calories  Total Fat (g)  \
# 0    Sandwiches            BBQ Chicken       330            4.0
# 1    Sandwiches                BBQ Rib       580           31.0
# 2    Sandwiches       Black Forest Ham       260            4.0
# 3    Sandwiches        Buffalo Chicken       360           12.0
# 4    Sandwiches  Chicken & Bacon Ranch       530           26.0
# ..          ...                    ...       ...            ...
# 181      Drinks    Simply Apple® Juice       160            0.0
# 182      Drinks      vitaminwater® XXX         0            0.0
# 183      Extras                  Bacon        70            6.0
# 184      Extras   Caramel Apple Cookie       210            6.0
# 185      Extras              Pepperoni        80            7.0
#
#      Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                  1.0            0.0                50          860
# ...

# %%
df["total_fat"] = df["Total Fat (g)"] + df["Saturated Fat (g)"] + df["Trans Fat (g)"]

# %%
df
# Out:
#        Category                   Item  Calories  Total Fat (g)  \
# 0    Sandwiches            BBQ Chicken       330            4.0
# 1    Sandwiches                BBQ Rib       580           31.0
# 2    Sandwiches       Black Forest Ham       260            4.0
# 3    Sandwiches        Buffalo Chicken       360           12.0
# 4    Sandwiches  Chicken & Bacon Ranch       530           26.0
# ..          ...                    ...       ...            ...
# 181      Drinks    Simply Apple® Juice       160            0.0
# 182      Drinks      vitaminwater® XXX         0            0.0
# 183      Extras                  Bacon        70            6.0
# 184      Extras   Caramel Apple Cookie       210            6.0
# 185      Extras              Pepperoni        80            7.0
#
#      Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                  1.0            0.0                50          860
# ...

# %%
df["total_miligram"] = df["Cholesterol (mg)"] + df["Sodium (mg)"]
df["total_gram"] = df["Carbs (g)"] + df["Dietary Fiber (g)"] + df["Sugars (g)"] + df["Protein (g)"]
df
df
# Out:
#        Category                   Item  Calories  Total Fat (g)  \
# 0    Sandwiches            BBQ Chicken       330            4.0
# 1    Sandwiches                BBQ Rib       580           31.0
# 2    Sandwiches       Black Forest Ham       260            4.0
# 3    Sandwiches        Buffalo Chicken       360           12.0
# 4    Sandwiches  Chicken & Bacon Ranch       530           26.0
# ..          ...                    ...       ...            ...
# 181      Drinks    Simply Apple® Juice       160            0.0
# 182      Drinks      vitaminwater® XXX         0            0.0
# 183      Extras                  Bacon        70            6.0
# 184      Extras   Caramel Apple Cookie       210            6.0
# 185      Extras              Pepperoni        80            7.0
#
#      Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0                  1.0            0.0                50          860
# ...

# %%
df.drop("Total Fat (g)",inplace = True, axis = 1)

# %%
df
# Out:
#        Category                   Item  Calories  Saturated Fat (g)  \
# 0    Sandwiches            BBQ Chicken       330                1.0
# 1    Sandwiches                BBQ Rib       580               10.0
# 2    Sandwiches       Black Forest Ham       260                1.5
# 3    Sandwiches        Buffalo Chicken       360                2.0
# 4    Sandwiches  Chicken & Bacon Ranch       530               10.0
# ..          ...                    ...       ...                ...
# 181      Drinks    Simply Apple® Juice       160                0.0
# 182      Drinks      vitaminwater® XXX         0                0.0
# 183      Extras                  Bacon        70                2.0
# 184      Extras   Caramel Apple Cookie       210                3.0
# 185      Extras              Pepperoni        80                2.5
#
#      Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  Carbs (g)  \
# 0              0.0                50          860         50
# ...

# %%
df.drop("Saturated Fat (g)", inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df.drop("Saturated Fat (g)", inplace = True, axis = 1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df.drop("Trans Fat (g)", inplace = True, axis = 1)

# %%
df.drop("Cholesterol (mg)", inplace = True, axis = 1)

# %%
df.drop("Sodium (mg)", inplace = True, axis = 1)

# %%
df.drop("Carbs (g)", inplace = True, axis = 1)

# %%
df.drop("Dietary Fiber (g)", inplace = True, axis = 1)

# %%
df.drop("Sugars (g)", inplace = True, axis = 1)

# %%
df.drop("Protein (g)", inplace = True, axis = 1)

# %%
df
# Out:
#        Category                   Item  Calories  Weight Watchers Pnts  \
# 0    Sandwiches            BBQ Chicken       330                 323.0
# 1    Sandwiches                BBQ Rib       580                 587.0
# 2    Sandwiches       Black Forest Ham       260                 251.5
# 3    Sandwiches        Buffalo Chicken       360                 343.0
# 4    Sandwiches  Chicken & Bacon Ranch       530                 510.0
# ..          ...                    ...       ...                   ...
# 181      Drinks    Simply Apple® Juice       160                 200.0
# 182      Drinks      vitaminwater® XXX         0                   0.0
# 183      Extras                  Bacon        70                  68.0
# 184      Extras   Caramel Apple Cookie       210                 237.0
# 185      Extras              Pepperoni        80                  79.5
#
#      total_fat  total_miligram  total_gram
# 0          5.0             910          92
# ...

# %%
sns.displot(df["Calories"]);

# %%
sns.histplot(df["Calories"]);

# %%
plt.pie(df["total_gram"])
plt.show()

# %%
plt.hist(df["total_fat"])
plt.show()

# %%
plt.scatter(df["Calories"],df["total_fat"])
plt.xlabel("Calories",size = 15)
plt.ylabel("total_fat",size = 15)
plt.show()

# %%
from scipy.stats import skew
from scipy import stats

# %%
sns.set(style="dark")
sns.distplot(df["total_fat"], fit=stats.norm)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = pd.read_csv("D:\\excel data\\superstoredata.csv",encoding="ISO-8859-1")

# %%
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11/08/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  11/08/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688  06/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9993    9994  CA-2017-119914  05/04/2017  05/09/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df1.drop("Customer Name",inplace = True, axis = 1)

# %%
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11/08/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  11/08/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688  06/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03/03/2017  Standard Class
# 9993    9994  CA-2017-119914  05/04/2017  05/09/2017    Second Class
#
#      Customer ID    Segment        Country             City       State  \
# ...

# %%
df1.drop("Ship Mode", inplace = True, axis = 1)

# %%
df1.drop("Country",inplace = True,axis = 1)

# %%
df1.drop("State",inplace = True, axis = 1)

# %%
df1.drop("Postal Code",inplace = True, axis = 1)

# %%
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date Customer ID    Segment  \
# 0          1  CA-2016-152156  11/08/2016  11/11/2016    CG-12520   Consumer
# 1          2  CA-2016-152156  11/08/2016  11/11/2016    CG-12520   Consumer
# 2          3  CA-2016-138688  06/12/2016   6/16/2016    DV-13045  Corporate
# 3          4  US-2015-108966  10/11/2015  10/18/2015    SO-20335   Consumer
# 4          5  US-2015-108966  10/11/2015  10/18/2015    SO-20335   Consumer
# ...      ...             ...         ...         ...         ...        ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    TB-21400   Consumer
# 9990    9991  CA-2017-121258   2/26/2017  03/03/2017    DB-13060   Consumer
# 9991    9992  CA-2017-121258   2/26/2017  03/03/2017    DB-13060   Consumer
# 9992    9993  CA-2017-121258   2/26/2017  03/03/2017    DB-13060   Consumer
# 9993    9994  CA-2017-119914  05/04/2017  05/09/2017    CC-12220   Consumer
#
# ...

# %%
df1.isnull().sum()
# Out:
# Row ID          0
# Order ID        0
# Order Date      0
# Ship Date       0
# Customer ID     0
# Segment         0
# City            0
# Region          0
# Product ID      0
# Category        0
# Sub-Category    0
# Product Name    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Ship Date     9994 non-null   object
#  4   Customer ID   9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   City          9994 non-null   object
#  7   Region        9994 non-null   object
#  8   Product ID    9994 non-null   object
#  9   Category      9994 non-null   object
#  10  Sub-Category  9994 non-null   object
#  11  Product Name  9994 non-null   object
#  12  Sales         9994 non-null   float64
#  13  Quantity      9994 non-null   int64
#  14  Discount      9994 non-null   float64
#  15  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 1.2+ MB

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Customer ID',
#        'Segment', 'City', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sns.displot(df1["Sales"])

# %%
plt.plot(df1["Sales"])
plt.show()

# %%
plt.plot(df1["Profit"])
plt.show()

# %%
plt.pie(df1["Quantity"])
plt.show()
