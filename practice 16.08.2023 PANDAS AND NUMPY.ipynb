# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([1,2,3,4])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
arr = np.array([1,2,5,6])
print(arr)
# Out:
# [1 2 5 6]

# %%
arr = np.array(25) # 0-d zero dimension array
print(arr)
# Out:
# 25

# %%
arr = np.array([1,2,3,4,5,6]) # 1-d dimension array
print(arr)
# Out:
# [1 2 3 4 5 6]

# %%
arr = np.array([[1,2,3],[4,5,6]]) # 2-d dimension array
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr = np.array([[[1,2],[2,3]],[[4,5],[5,6]]])
print(arr)
# Out:
# [[[1 2]
#   [2 3]]
#
#  [[4 5]
#   [5 6]]]

# %%
arr = np.array([[1,2,3],[4,5,6]])
print("Size: ", arr.size)
print("shape: ", arr.shape)
# Out:
# Size:  6
# shape:  (2, 3)

# %%
arr = np.array([1,2,3], ndmin = 4)
print(arr)
print(arr.ndim)
# Out:
# [[[[1 2 3]]]]
# 4

# %%
import pandas as pd

# %%
mydataset = {
    "name" : ["komal","pooja","chirag"],
    "age" : [20,30,33]
}

a = pd.DataFrame(mydataset)
print(a)
# Out:
#      name  age
# 0   komal   20
# 1   pooja   30
# 2  chirag   33

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %%
mydataset = {
    "CarName" : ["maruti","ford","kia","hundai"],
    "prize" : [360000,900000,650000,780000]
}

data_store = pd.DataFrame(mydataset)
print(data_store)
# Out:
#   CarName   prize
# 0  maruti  360000
# 1    ford  900000
# 2     kia  650000
# 3  hundai  780000

# %%
print(pd.DataFrame(mydataset))
# Out:
#   CarName   prize
# 0  maruti  360000
# 1    ford  900000
# 2     kia  650000
# 3  hundai  780000

# %%
a = ["a","b"]
b = [1,2,3]
print(pd.Series(a))
print(pd.Series(b))
# Out:
# 0    a
# 1    b
# dtype: object
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
t = [1,2,3,4]
print(pd.Series(t,index = ["A","B","C","D"]))
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
cardetails = {"name": "maruti","prize": 500000,"model": "mmj853"}
print(pd.Series(cardetails))
# Out:
# name     maruti
# prize    500000
# model    mmj853
# dtype: object

# %%
student_data = {
    "name": ["kesha","pooja","chirag","rushi"],
    "age" : [20,25,30,28],
    "study" : ["MCA", "BCOM", "CA", "BSC"]
}

std_data = pd.DataFrame(student_data, index = ["x","y","z","w"])
std_data
# Out:
#      name  age study
# x   kesha   20   MCA
# y   pooja   25  BCOM
# z  chirag   30    CA
# w   rushi   28   BSC

# %%
print(pd.DataFrame(student_data, index = ["a","b","c","d"]))
# Out:
#      name  age study
# a   kesha   20   MCA
# b   pooja   25  BCOM
# c  chirag   30    CA
# d   rushi   28   BSC

# %%
std_data
# Out:
#      name  age study
# x   kesha   20   MCA
# y   pooja   25  BCOM
# z  chirag   30    CA
# w   rushi   28   BSC

# %%
d = std_data.loc[['x','y'],'name']

# %%
d
# Out:
# x    kesha
# y    pooja
# Name: name, dtype: object

# %%
std_data.iloc[1:,1]
# Out:
# y    25
# z    30
# w    28
# Name: age, dtype: int64

# %%
std_data["name"] = ["kesha","pooja","chirag","rushi"]
std_data
# Out:
#      name  age study
# x   kesha   20   MCA
# y   pooja   25  BCOM
# z  chirag   30    CA
# w   rushi   28   BSC

# %%
std_data["address"] = ["ahmedabad","pune","indore","goa"]
std_data
# Out:
#      name  age study    address
# x   kesha   20   MCA  ahmedabad
# y   pooja   25  BCOM       pune
# z  chirag   30    CA     indore
# w   rushi   28   BSC        goa

# %%
std_data['x1']=['q',12,'er',4]

# %%
std_data
# Out:
#      name  age study    address  x1
# x   kesha   20   MCA  ahmedabad   q
# y   pooja   25  BCOM       pune  12
# z  chirag   30    CA     indore  er
# w   rushi   28   BSC        goa   4

# %%
std_data1 = pd.DataFrame({
    "name" : ["glass","plastic"],
    "weight" : [2.5,0.6],
    "size" : ["small","medium"]
})

std_data = std_data.append(std_data1)
std_data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2704\2565857858.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   std_data = std_data.append(std_data1)
#       name   age study  maya   x1  weight    size
# x    kesha  20.0   MCA   NaN    q     NaN     NaN
# y    pooja  25.0  BCOM   NaN   12     NaN     NaN
# z   chirag  30.0    CA   NaN   er     NaN     NaN
# w    rushi  28.0   BSC   NaN    4     NaN     NaN
# v      NaN   NaN   NaN   NaN    9     NaN     NaN
# 0    glass   NaN   NaN   NaN  NaN     2.5   small
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium
# 0    glass   NaN   NaN   NaN  NaN     2.5   small
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium

# %%
std_data["index"] = [0,1,2,3,4,5,6,7,8]
std_data
# Out:
#       name   age study  maya   x1  weight    size  index
# x    kesha  20.0   MCA   NaN    q     NaN     NaN      0
# y    pooja  25.0  BCOM   NaN   12     NaN     NaN      1
# z   chirag  30.0    CA   NaN   er     NaN     NaN      2
# w    rushi  28.0   BSC   NaN    4     NaN     NaN      3
# v      NaN   NaN   NaN   NaN    9     NaN     NaN      4
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      5
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      6
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      7
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      8

# %%
std_dat = std_data.drop("x") # row drop
std_dat
# Out:
#       name   age study  maya   x1  weight    size  index
# y    pooja  25.0  BCOM   NaN   12     NaN     NaN      1
# z   chirag  30.0    CA   NaN   er     NaN     NaN      2
# w    rushi  28.0   BSC   NaN    4     NaN     NaN      3
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      5
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      6
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      7
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      8

# %%
std_data
# Out:
#       name   age study  maya   x1  weight    size  index
# x    kesha  20.0   MCA   NaN    q     NaN     NaN      0
# y    pooja  25.0  BCOM   NaN   12     NaN     NaN      1
# z   chirag  30.0    CA   NaN   er     NaN     NaN      2
# w    rushi  28.0   BSC   NaN    4     NaN     NaN      3
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      5
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      6
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      7
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      8

# %%
std_dat
# Out:
#       name   age study  maya   x1  weight    size  index
# y    pooja  25.0  BCOM   NaN   12     NaN     NaN      1
# z   chirag  30.0    CA   NaN   er     NaN     NaN      2
# w    rushi  28.0   BSC   NaN    4     NaN     NaN      3
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      5
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      6
# 0    glass   NaN   NaN   NaN  NaN     2.5   small      7
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium      8

# %%
std_dat
# Out:
#       name   age study  maya   x1  weight    size
# y    pooja  25.0  BCOM   NaN   12     NaN     NaN
# z   chirag  30.0    CA   NaN   er     NaN     NaN
# w    rushi  28.0   BSC   NaN    4     NaN     NaN
# 0    glass   NaN   NaN   NaN  NaN     2.5   small
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium
# 0    glass   NaN   NaN   NaN  NaN     2.5   small
# 1  plastic   NaN   NaN   NaN  NaN     0.6  medium

# %%
std_dat.drop(["x1"],axis=1,inplace = True)
std_dat
# Out:
#       name   age study  maya  weight    size
# y    pooja  25.0  BCOM   NaN     NaN     NaN
# z   chirag  30.0    CA   NaN     NaN     NaN
# w    rushi  28.0   BSC   NaN     NaN     NaN
# 0    glass   NaN   NaN   NaN     2.5   small
# 1  plastic   NaN   NaN   NaN     0.6  medium
# 0    glass   NaN   NaN   NaN     2.5   small
# 1  plastic   NaN   NaN   NaN     0.6  medium

# %%
stationary = ({
    "Books" : ["mathamatics","science"],
    "Std" : ["std-11","std-12"],
    "Rate" : [250,360]
})

stnr = pd.DataFrame(stationary)
stnr
# Out:
#          Books     Std  Rate
# 0  mathamatics  std-11   250
# 1      science  std-12   360

# %%
stat = ({
    "Books" : ["economics"],
    "Std" :["arts"],
    "Rate" : [2000]
})

stat1 = stnr.append(stat,ignore_index = True)
stat1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2704\2995571883.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stat1 = stnr.append(stat,ignore_index = True)
#          Books     Std    Rate
# 0  mathamatics  std-11     250
# 1      science  std-12     360
# 2  [economics]  [arts]  [2000]

# %%
stnr.loc[2] = ["maths","std-4",200]
stnr
# Out:
#              Books     Std  Rate
# 0      mathamatics  std-11   250
# 1          science  std-12   360
# books        maths   std-4   200
# 2            maths   std-4   200
# 3            maths   std-5   800
# 4            maths  std-10   900
# 5            maths   std-7   200

# %%
#row wise data frame
stnr.loc[3] = ["maths","std-3",300]
stnr.loc[4] = ["maths","std-5",800]
stnr.loc[5] = ["maths","std-10",900]
stnr.loc[6] = ["maths","std-7",200]
stnr.loc[7] = ["economics","arts", 2500]
stnr.loc[8] = ["bailogy","science", 3500]
stnr.loc[9] = ["chemistry","science", 3000]
stnr.loc[10] = ["accountant","commerce", 4500]
stnr
# Out:
#              Books       Std  Rate
# 0      mathamatics    std-11   250
# 1          science    std-12   360
# books        maths     std-4   200
# 2            maths     std-4   200
# 3            maths     std-3   300
# 4            maths     std-5   800
# 5            maths    std-10   900
# 6            maths     std-7   200
# 7        economics      arts  2500
# 8          bailogy   science  3500
# 9        chemistry   science  3000
# 10      accountant  commerce  4500

# %%
# column wise add data frame
stnr["ballpen"] = ["red","ink-pan","black","marker","marker","blue","blue","gel-pen","red","blue","white-marker","blue"]
stnr["headphone"]= ["i-ball","boat","zoom","apple","MI","MI","boat","apple","apple","i-ball","dell","MI"]
stnr["plastic"] = ["waterbottle", "giftpaper","phonecover","waterbottle","giftpaper","giftpaper","phonecover","phonecover","phonecover","waterbottle","giftpaper","giftpaper"]
stnr
# Out:
#              Books       Std  Rate       ballpen headphone      plastic
# 0      mathamatics    std-11   250           red    i-ball  waterbottle
# 1          science    std-12   360       ink-pan      boat    giftpaper
# books        maths     std-4   200         black      zoom   phonecover
# 2            maths     std-4   200        marker     apple  waterbottle
# 3            maths     std-3   300        marker        MI    giftpaper
# 4            maths     std-5   800          blue        MI    giftpaper
# 5            maths    std-10   900          blue      boat   phonecover
# 6            maths     std-7   200       gel-pen     apple   phonecover
# 7        economics      arts  2500           red     apple   phonecover
# 8          bailogy   science  3500          blue    i-ball  waterbottle
# 9        chemistry   science  3000  white-marker      dell    giftpaper
# 10      accountant  commerce  4500          blue        MI    giftpaper

# %%
stnr.drop(["books"],axis = 0, inplace = True) # row wise delete data
stnr
# Out:
#           Books       Std  Rate       ballpen headphone      plastic
# 0   mathamatics    std-11   250           red    i-ball  waterbottle
# 1       science    std-12   360       ink-pan      boat    giftpaper
# 2         maths     std-4   200        marker     apple  waterbottle
# 3         maths     std-3   300        marker        MI    giftpaper
# 4         maths     std-5   800          blue        MI    giftpaper
# 5         maths    std-10   900          blue      boat   phonecover
# 6         maths     std-7   200       gel-pen     apple   phonecover
# 7     economics      arts  2500           red     apple   phonecover
# 8       bailogy   science  3500          blue    i-ball  waterbottle
# 9     chemistry   science  3000  white-marker      dell    giftpaper
# 10   accountant  commerce  4500          blue        MI    giftpaper

# %%
stnr.drop(["plastic"], axis = 1 , inplace = True) # column wise data delete
stnr
# Out:
#           Books       Std  Rate       ballpen headphone
# 0   mathamatics    std-11   250           red    i-ball
# 1       science    std-12   360       ink-pan      boat
# 2         maths     std-4   200        marker     apple
# 3         maths     std-3   300        marker        MI
# 4         maths     std-5   800          blue        MI
# 5         maths    std-10   900          blue      boat
# 6         maths     std-7   200       gel-pen     apple
# 7     economics      arts  2500           red     apple
# 8       bailogy   science  3500          blue    i-ball
# 9     chemistry   science  3000  white-marker      dell
# 10   accountant  commerce  4500          blue        MI

# %%
mydata_frame = pd.read_csv("C:\\Users\\Admin\\Desktop\\employee details.csv")
mydata_frame
# Out:
#         NAME  AGE  SALARY position
# 0      komal   30   25000   junior
# 1      pooja   20   15000   senior
# 2     vishal   20   30000   junior
# 3     chirag   32   35000   senior
# 4      rushi   25   10000   junior
# 5  peppa pig   20   50000   senior
# 6      mansi   35   35000   senior

# %%
mydata_frame.loc[7] = ["kesha",22,19000,"junior"]
mydata_frame.loc[8] = ["kumudi",35,35000,"senior"]
mydata_frame.loc[9] = ["vishakha",22,11000,"junior"]
mydata_frame.loc[10] = ["vishnu",42,49000,"senior"]
mydata_frame
# Out:
#          NAME  AGE  SALARY position
# 0       komal   30   25000   junior
# 1       pooja   20   15000   senior
# 2      vishal   20   30000   junior
# 3      chirag   32   35000   senior
# 4       rushi   25   10000   junior
# 5   peppa pig   20   50000   senior
# 6       mansi   35   35000   senior
# 7       kesha   22   19000   junior
# 8      kumudi   35   35000   senior
# 9    vishakha   22   11000   junior
# 10     vishnu   42   49000   senior

# %%
from datetime import datetime 
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (8, .2))
ax = fig.add_subplot(111)

ax.table(cellText = mydata_frame.values, rowLabels = mydata_frame.index,colLabels = mydata_frame.columns, cellLoc='center')

ax.set_title("Employee Details")

ax.axis('off')


mydata_frame["joining-date"] = ['03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022']
mydata_frame["resigning-date"] = ['03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022','03/03/2022']
mydata_frame
# Out:
#          NAME  AGE  SALARY position joining-date resigning-date
# 0       komal   30   25000   junior   03/03/2022     03/03/2022
# 1       pooja   20   15000   senior   03/03/2022     03/03/2022
# 2      vishal   20   30000   junior   03/03/2022     03/03/2022
# 3      chirag   32   35000   senior   03/03/2022     03/03/2022
# 4       rushi   25   10000   junior   03/03/2022     03/03/2022
# 5   peppa pig   20   50000   senior   03/03/2022     03/03/2022
# 6       mansi   35   35000   senior   03/03/2022     03/03/2022
# 7       kesha   22   19000   junior   03/03/2022     03/03/2022
# 8      kumudi   35   35000   senior   03/03/2022     03/03/2022
# 9    vishakha   22   11000   junior   03/03/2022     03/03/2022
# 10     vishnu   42   49000   senior   03/03/2022     03/03/2022

# %%
print(mydata_frame.loc[3:5,["NAME","joining-date"]]) # selected data display
# Out:
#         NAME joining-date
# 3     chirag   03/03/2022
# 4      rushi   03/03/2022
# 5  peppa pig   03/03/2022
