# %% [markdown]
# # feature scaling

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("D:\\excel data\\houseprize advanced\\train.csv")

# %%
df.sample(5)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea Neighborhood BldgType HouseStyle  \
# 80      81          60        100.0    13000        NAmes     1Fam     2Story
# 13      14          20         91.0    10652      CollgCr     1Fam     1Story
# 251    252         120         44.0     4750      Crawfor   TwnhsE     1Story
# 1148  1149          50          NaN     5700      OldTown     1Fam     1.5Fin
# 1366  1367          60         68.0     9179      CollgCr     1Fam     2Story
#
#       OverallQual  OverallCond  YearBuilt  ...  OpenPorchSF  EnclosedPorch  \
# 80              6            6       1968  ...           72              0
# 13              7            5       2006  ...           33              0
# 251             8            5       2006  ...            0              0
# 1148            7            7       1926  ...            0            176
# 1366            7            5       1999  ...           88              0
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'Neighborhood',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# Neighborhood       0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleCondition      0
# SalePrice          0
# dtype: int64

# %%
sns.countplot(df["YearBuilt"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df["SalePrice"])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
sns.boxplot(df["YearBuilt"])
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df.drop("SalePrice",axis = 1),df["SalePrice"],test_size = 0.2,random_state = 1)

# %%
x_train.drop("Neighborhood",axis = 1,inplace = True)

# %%
x_train.drop("HouseStyle", axis = 1, inplace = True)

# %%
x_train.drop("BldgType",axis = 1,inplace = True)

# %%
x_train["SaleCondition"] = x_train["SaleCondition"].replace({"Normal": 1,"Partial": 0,"Abnorml":2,"Family": 3,"Alloca": 4,"AdjLand":5})
x_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 921    922          90         67.0     8777            5            7
# 520    521         190         60.0    10800            4            7
# 401    402          20         65.0     8767            7            5
# 280    281          60         82.0    11287            7            6
# 1401  1402          60         62.0     7415            6            5
# ...    ...         ...          ...      ...          ...          ...
# 715    716          20         78.0    10140            6            5
# 905    906          20         80.0     9920            5            5
# 1096  1097          70         60.0     6882            6            7
# 235    236         160         21.0     1680            6            3
# 1061  1062          30        120.0    18000            3            4
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
x_train.shape
# Out:
# (1168, 37)

# %%
x_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleCondition'],
#       dtype='object')

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
scaler.transform(x_train)
# Out:
# array([[ 0.44531816,  0.79087217, -0.12932832, ...,  1.00778724,
#          0.13313862, -0.08219835],
#        [-0.4995788 ,  3.16827199, -0.4112968 , ...,  0.63575959,
#          0.13313862, -0.08219835],
#        [-0.77998463, -0.8733077 , -0.20989074, ...,  0.26373193,
#         -1.3766275 , -1.86011824],
#        ...,
#        [ 0.85767967,  0.31539221, -0.4112968 , ..., -1.22437868,
#         -0.62174444, -0.08219835],
#        [-1.17113898,  2.45505205, -1.9822641 , ...,  0.63575959,
#          0.13313862, -0.08219835],
#        [ 0.77520737, -0.63556772,  2.00557596, ...,  0.63575959,
#          0.13313862, -0.08219835]])

# %%
y_train
# Out:
# 921     145900
# 520     106250
# 401     164990
# 280     228500
# 1401    193000
#          ...
# 715     165000
# 905     128000
# 1096    127000
# 235      89500
# 1061     81000
# Name: SalePrice, Length: 1168, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'Neighborhood',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
sns.scatterplot(x_train)
# Out:
# <Axes: >

# %%
sns.scatterplot(y_train)
# Out:
# <Axes: ylabel='SalePrice'>
