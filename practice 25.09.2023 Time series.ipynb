# %%
from pandas_datareader import data as pdr
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
import yfinance as yf
yf.pdr_override()

# %%
df = pdr.get_data_yahoo("TSLA",start = "2015-01-01",end = "2022-12-01")
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-02   14.858000   14.883333   14.217333   14.620667   14.620667
# 2015-01-05   14.303333   14.433333   13.810667   14.006000   14.006000
# 2015-01-06   14.004000   14.280000   13.614000   14.085333   14.085333
# 2015-01-07   14.223333   14.318667   13.985333   14.063333   14.063333
# 2015-01-08   14.187333   14.253333   14.000667   14.041333   14.041333
# ...                ...         ...         ...         ...         ...
# 2022-11-23  173.570007  183.619995  172.500000  183.199997  183.199997
# 2022-11-25  185.059998  185.199997  180.630005  182.860001  182.860001
# 2022-11-28  179.960007  188.500000  179.000000  182.919998  182.919998
# 2022-11-29  184.990005  186.380005  178.750000  180.830002  180.830002
# 2022-11-30  182.429993  194.759995  180.630005  194.699997  194.699997
#
#                Volume
# Date
# ...

# %%
df["Open"].plot(figsize = (12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Open"].plot(xlim = ["2019-01-01","2022-01-01"],ylim = [0,450],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21',
#                '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28',
#                '2022-11-29', '2022-11-30'],
#               dtype='datetime64[ns]', name='Date', length=1993, freq=None)

# %%
index = df.loc["2019-01-01":"2022-12-01"].index
index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2022-11-16', '2022-11-17', '2022-11-18', '2022-11-21',
#                '2022-11-22', '2022-11-23', '2022-11-25', '2022-11-28',
#                '2022-11-29', '2022-11-30'],
#               dtype='datetime64[ns]', name='Date', length=987, freq=None)

# %%
share_open = df.loc["2019-01-01":"2022-12-01"]["Open"]
share_open
# Out:
# Date
# 2019-01-02     20.406668
# 2019-01-03     20.466667
# 2019-01-04     20.400000
# 2019-01-07     21.448000
# 2019-01-08     22.797333
#                  ...
# 2022-11-23    173.570007
# 2022-11-25    185.059998
# 2022-11-28    179.960007
# 2022-11-29    184.990005
# 2022-11-30    182.429993
# Name: Open, Length: 987, dtype: float64

# %%
figure,axis = plt.subplots(figsize = (10,4))
axis.plot(index,share_open)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1993 entries, 2015-01-02 to 2022-11-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1993 non-null   float64
#  1   High       1993 non-null   float64
#  2   Low        1993 non-null   float64
#  3   Close      1993 non-null   float64
#  4   Adj Close  1993 non-null   float64
#  5   Volume     1993 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 173.5 KB

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 9, 23, 15, 11, 13, 216137)

# %%
date = datetime(2023, 9, 23)

# %%
date
# Out:
# datetime.datetime(2023, 9, 23, 0, 0)

# %%
date.day
# Out:
# 23

# %%
date.month
# Out:
# 9

# %%
df.resample(rule="B")

# %%
df.resample(rule="B").min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-02   14.858000   14.883333   14.217333   14.620667   14.620667
# 2015-01-05   14.303333   14.433333   13.810667   14.006000   14.006000
# 2015-01-06   14.004000   14.280000   13.614000   14.085333   14.085333
# 2015-01-07   14.223333   14.318667   13.985333   14.063333   14.063333
# 2015-01-08   14.187333   14.253333   14.000667   14.041333   14.041333
# ...                ...         ...         ...         ...         ...
# 2022-11-24         NaN         NaN         NaN         NaN         NaN
# 2022-11-25  185.059998  185.199997  180.630005  182.860001  182.860001
# 2022-11-28  179.960007  188.500000  179.000000  182.919998  182.919998
# 2022-11-29  184.990005  186.380005  178.750000  180.830002  180.830002
# 2022-11-30  182.429993  194.759995  180.630005  194.699997  194.699997
#
#                  Volume
# Date
# 2015-01-02   71466000.0
# 2015-01-05   80527500.0
# 2015-01-06   93928500.0
# ...

# %%
df.resample(rule="A").min()["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close"].resample(rule="BA").mean().plot(kind = "bar")
# Out:
# <Axes: xlabel='Date'>

# %%
df["High"].resample(rule="BA").mean().plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["High"].resample(rule="M").max().plot(kind = "bar",figsize = (15,9))
# Out:
# <Axes: xlabel='Date'>

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667  71466000
# 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000  80527500
# 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333  93928500
# 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333  44526000
# 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333  51637500

# %%
df["Close"].rolling(5).mean().head()
# Out:
# Date
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08    14.163333
# Name: Close, dtype: float64

# %%
df["Open: 20 days rolling"]= df["Close"].rolling(20).mean()

# %%
df[["Open","Open: 20 days rolling"]].plot(figsize = (15,5))
# Out:
# <Axes: xlabel='Date'>
