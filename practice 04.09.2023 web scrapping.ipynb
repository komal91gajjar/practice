# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\excel data\\IPLdata.csv")

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop("neutral_venue")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df.drop("neutral_venue")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %%
df.iloc("neutral_venue")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'neutral_venue'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df.iloc("neutral_venue")
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:634, in _LocationIndexer.__call__(self, axis)
#     631 new_self = type(self)(self.name, self.obj)
#     633 if axis is not None:
# --> 634     axis = self.obj._get_axis_number(axis)
#     635 new_self.axis = axis
#     636 return new_self
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.drop("neutral_venue",axis = 1)
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
empty_columns = df.columns[df.isna().all() | (df.astype(str) == '').all()]

# %%
print(empty_columns)
# Out:
# Index([], dtype='object')

# %%
empty_column = df.columns[df.isna().all() | (df.astype(str) == " ").all()]
print(empty_column)
# Out:
# Index([], dtype='object')

# %%
empty_rows = df[df.isna().all(axis=1) | (df.astype(str) == '').all(axis=1)]

# %%
df.isna().all()
# Out:
# id                 False
# city               False
# date               False
# player_of_match    False
# venue              False
# neutral_venue      False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# winner             False
# result             False
# result_margin      False
# eliminator         False
# method             False
# umpire1            False
# umpire2            False
# dtype: bool

# %%
empty_rows = df[df.isna().all(axis=1) | (df.astype(str) == " ").all(axis=1)]

# %%
print(empty_rows)
# Out:
# Empty DataFrame
# Columns: [id, city, date, player_of_match, venue, neutral_venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, eliminator, method, umpire1, umpire2]
# Index: []

# %%
df.drop("eliminator",axis = 1)
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop("method",inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df.drop("method",inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %%
df.drop("neutral_venue",inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df.drop("neutral_venue",inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop("eliminator", axis=1, inplace = True)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop("method", axis=1, inplace = True)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop("neutral_venue", axis=1, inplace = True)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %%
plt.plot(df["toss_decision"],df["result_margin"])
plt.xlabel("Toss_decision",size = 15,color = "blue")
plt.ylabel("Result_margin",size = 15,color = "blue")
plt.grid()
plt.show()

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18/04/2008     BB McCullum
# 1     335983  Chandigarh  19/04/2008      MEK Hussey
# 2     335984       Delhi  19/04/2008     MF Maharoof
# 3     335985      Mumbai  20/04/2008      MV Boucher
# 4     335986     Kolkata  20/04/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28/09/2020  AB de Villiers
# 812  1237177       Dubai  05/11/2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06/11/2020   KS Williamson
# 814  1237180   Abu Dhabi  08/11/2020      MP Stoinis
# 815  1237181       Dubai  10/11/2020        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# ...

# %%
plt.scatter(df["team1"],df["team2"])
plt.show()

# %%
! pip install Beautiulsoup4
# Out:
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\admin\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement Beautiulsoup4 (from versions: none)
# ERROR: No matching distribution found for Beautiulsoup4
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\admin\anaconda3\lib\site-packages)

# %%
import requests
from bs4 import BeautifulSoup

# %%
requests.get("https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav").text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;cf8c2c31&#46;1693807578&#46;103c3c1d\n</BODY>\n</HTML>\n'

# %%
# Send an HTTP request to the website
url = 'https://example.com/news'
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Find and extract the titles of articles
article_titles = soup.find_all('h2', class_='article-title')
for title in article_titles:
    print(title.text)

# %%
df = pd.read_csv("D:\\excel data\\aug_train.csv")

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.shape
# Out:
# (19158, 14)

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %%
df.sample(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 14461        11344  city_103                   0.920   Male
# 1366         32990   city_21                   0.624    NaN
# 12235        17247   city_21                   0.624    NaN
# 18609         7291  city_103                   0.920    NaN
# 3490          2792  city_173                   0.878   Male
#
#            relevent_experience enrolled_university education_level  \
# 14461  Has relevent experience       no_enrollment        Graduate
# 1366   Has relevent experience    Full time course             NaN
# 12235  Has relevent experience       no_enrollment        Graduate
# 18609  Has relevent experience       no_enrollment        Graduate
# 3490   Has relevent experience       no_enrollment         Masters
#
#       major_discipline experience company_size         company_type  \
# 14461             STEM          5      500-999              Pvt Ltd
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()["training_hours"]
# Out:
# enrollee_id               0.000998
# city_development_index    0.001920
# training_hours            1.000000
# target                   -0.021577
# Name: training_hours, dtype: float64

# %%
df.corr()
# Out:
#                         enrollee_id  city_development_index  training_hours  \
# enrollee_id                1.000000               -0.040455        0.000998
# city_development_index    -0.040455                1.000000        0.001920
# training_hours             0.000998                0.001920        1.000000
# target                     0.049475               -0.341665       -0.021577
#
#                           target
# enrollee_id             0.049475
# city_development_index -0.341665
# training_hours         -0.021577
# target                  1.000000

# %%
Df = pd.read_csv("D:\\excel data\\titanic data set\\train.csv")

# %%
Df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Df.sample(6)
# Out:
#      PassengerId  Survived  Pclass  \
# 581          582         1       1
# 356          357         1       1
# 885          886         0       3
# 872          873         0       1
# 553          554         1       3
# 591          592         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 581  Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
# 356                        Bowerman, Miss. Elsie Edith  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 553                  Leeni, Mr. Fahim ("Philip Zenni")    male  22.0      0
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
#
#      Parch  Ticket      Fare        Cabin Embarked
# 581      1   17421  110.8833          C68        C
# 356      1  113505   55.0000          E33        S
# ...

# %%
Df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns

# %%
sns.countplot(Df["Survived"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(Df["Pclass"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(Df["Age"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
Df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(Df["Embarked"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(Df["SibSp"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(Df["Parch"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
sns.countplot(Df["Name"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Name', ylabel='count'>

# %%
sns.countplot(Df["Sex"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
Df["Sex"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
Df["Age"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
Df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
Df["Embarked"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Embarked'>

# %%
Df["Pclass"].value_counts().plot(kind = "pie", autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
plt.hist(Df["Age"],bins = 20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.show()

# %%
sns.distplot(Df["Age"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(Df["Fare"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
sns.boxplot(Df["Age"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>
