# %% [markdown]
# #Pivot Table

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
df.groupby(["sex","smoker"])[["total_bill"]].mean().unstack()
# Out:
#        total_bill
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
df.pivot_table(index="sex",columns="smoker",values="total_bill")
# Out:
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
# Multidimensional

df.pivot_table(index = ["sex","smoker"], columns=["day","time"],values="total_bill")
# Out:
# day                 Thur               Fri                Sat        Sun
# time               Lunch Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes     19.171000    NaN  11.386667  25.892  21.837778  26.141333
#        No      18.486500    NaN        NaN  17.475  19.929063  20.403256
# Female Yes     19.218571    NaN  13.260000  12.200  20.266667  16.540000
#        No      15.899167  18.78  15.980000  22.750  19.003846  20.824286

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
# use to aggarigate function

df.pivot_table(index=["sex","smoker"],columns=["day","time"],aggfunc = {"tip":"sum","size":"max","total_bill":"mean"})
# Out:
#                size                                      tip               \
# day            Thur          Fri           Sat    Sun   Thur          Fri
# time          Lunch Dinner Lunch Dinner Dinner Dinner  Lunch Dinner Lunch
# sex    smoker
# Male   Yes      4.0    NaN   2.0    4.0    5.0    5.0  30.58    0.0  5.70
#        No       6.0    NaN   NaN    2.0    4.0    6.0  58.83    0.0  0.00
# Female Yes      4.0    NaN   2.0    2.0    4.0    3.0  20.93    0.0  7.98
#        No       6.0    2.0   3.0    2.0    4.0    5.0  58.49    3.0  3.00
#
#                                                  total_bill                    \
# day                    Sat           Sun               Thur               Fri
# time          Dinner Lunch  Dinner Lunch  Dinner      Lunch Dinner      Lunch
# sex    smoker
# Male   Yes     16.23   0.0   77.74   0.0   52.82  19.171000    NaN  11.386667
#        No       5.00   0.0  104.21   0.0  133.96  18.486500    NaN        NaN
# ...

# %%
# margins
df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum",margins=True)
# Out:
# smoker      Yes       No      All
# sex
# Male    1337.07  1919.75  3256.82
# Female   593.27   977.68  1570.95
# All     1930.34  2897.43  4827.77

# %%
# without using aggarigate function use to margins function
df.pivot_table(index="sex",columns="smoker",values="total_bill",margins=True)
# Out:
# smoker        Yes         No        All
# sex
# Male    22.284500  19.791237  20.744076
# Female  17.977879  18.105185  18.056897
# All     20.756344  19.188278  19.785943

# %%
#plotting gragh

plot = pd.read_csv("D:\\excel data\\expense_data.csv")

# %%
plot.head(5)
# Out:
#                Date               Account        Category  Subcategory  \
# 0  03/02/2022 10:11  CUB - online payment            Food          NaN
# 1  03/02/2022 10:11  CUB - online payment           Other          NaN
# 2  03/01/2022 19:50  CUB - online payment            Food          NaN
# 3  03/01/2022 18:56  CUB - online payment  Transportation          NaN
# 4  03/01/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
plot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
plot['Date'] = pd.to_datetime(plot['Date'])

# %%
plot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
plot["month"] = plot["Date"].dt.month_name()

# %%
plot.head(3)
# Out:
#                  Date               Account Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment     Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment    Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment     Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
#
#    month
# 0  March
# 1  March
# 2  March

# %%
plot["year"] = plot["Date"].dt.year

# %%
plot.head(3)
# Out:
#                  Date               Account Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment     Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment    Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment     Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
#
#    month  year
# 0  March  2022
# 1  March  2022
# 2  March  2022

# %%
plot.pivot_table(index="month",columns="Category",values="INR",aggfunc="sum")
# Out:
# Category  Allowance  Apparel  Beauty  Education     Food   Gift  Household  \
# month
# December    11000.0   2590.0   196.0        NaN  6440.72    NaN     4800.0
# February        NaN    798.0     NaN        NaN  5579.85    NaN     2808.0
# January      1000.0      NaN     NaN     1400.0  9112.51    NaN     4580.0
# March           NaN      NaN     NaN        NaN   195.00    NaN        NaN
# November     2000.0      NaN     NaN        NaN  3174.40  115.0        NaN
#
# Category    Other  Petty cash  Salary  Self-development  Social Life  \
# month
# December   1790.0         NaN     NaN             400.0       513.72
# February  20000.0         NaN     NaN               NaN      1800.00
# January   13178.0         NaN  8000.0               NaN       200.00
# March       900.0         NaN     NaN               NaN          NaN
# November   2000.0         3.0     NaN               NaN          NaN
#
# Category  Transportation
# month
# December           914.0
# ...

# %%
plot.pivot_table(index="month",columns="Category",values="INR",aggfunc="sum").plot()
# Out:
# <Axes: xlabel='month'>

# %%
plot.pivot_table(index="month",columns="Income/Expense",values="INR",aggfunc="sum").plot()
# Out:
# <Axes: xlabel='month'>

# %%
plot.pivot_table(index="month",columns="Account",values="INR",aggfunc="sum").plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
plot.pivot_table(index="month",columns="Account",values="INR",aggfunc="sum").plot()
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ##Vectoried String Operation

# %%
# problem in vectorized operation in python

s = ["cat","rat","mat",None,"match"]

[i.startswith("c") for i in s]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\visual studio data\practice 16.10.2023 pandas function.ipynb Cell 29 line 5
#       <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.10.2023%20pandas%20function.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> # problem in vectorized operation in python
#       <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.10.2023%20pandas%20function.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> s = ["cat","rat","mat",None,"match"]
# ----> <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.10.2023%20pandas%20function.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a> [i.startswith("c") for i in s]
#
# d:\visual studio data\practice 16.10.2023 pandas function.ipynb Cell 29 line 5
# ...

# %%
# How solve this problem in python

s = pd.Series(["cat","rat","mat",None,"match"])
# string accessor
s.str.startswith("c")
# Out:
# 0     True
# 1    False
# 2    False
# 3     None
# 4    False
# dtype: object

# %% [markdown]
# #import dataset

# %%
titanic = pd.read_csv("D:\\excel data\\titanic.csv")

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#len()
titanic["Name"][titanic["Name"].str.len() == 82].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
#strip()
"                apple             ".strip()
# Out:
# 'apple'

# %%
titanic["Name"].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#split()

titanic["Name"].str.split()
# Out:
# 0                           [Braund,, Mr., Owen, Harris]
# 1      [Cumings,, Mrs., John, Bradley, (Florence, Bri...
# 2                             [Heikkinen,, Miss., Laina]
# 3      [Futrelle,, Mrs., Jacques, Heath, (Lily, May, ...
# 4                          [Allen,, Mr., William, Henry]
#                              ...
# 886                            [Montvila,, Rev., Juozas]
# 887                    [Graham,, Miss., Margaret, Edith]
# 888       [Johnston,, Miss., Catherine, Helen, "Carrie"]
# 889                           [Behr,, Mr., Karl, Howell]
# 890                              [Dooley,, Mr., Patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic["LastName"] = titanic["Name"].str.split(",").str.get(0)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[["Title","Firstname"]] = titanic["Name"].str.split(",").str.get(1).str.strip().str.split(" ", n = 1, expand=True)

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   LastName  Title  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund    Mr.
# 1      0          PC 17599  71.2833   C85        C    Cumings   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen  Miss.
# ...

# %%
titanic["Title"].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
#replace
titanic["Title"] = titanic["Title"].str.replace("Ms.","Miss.")
titanic["Title"] = titanic["Title"].str.replace("Mlle.","Miss.")

# %%
titanic["Title"].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        185
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Major.         2
# Col.           2
# Don.           1
# Mme.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
titanic[titanic["Firstname"].str.startswith("A")]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 13            14         0       3         Andersson, Mr. Anders Johan
# 22            23         1       3         McGowan, Miss. Anna "Annie"
# 35            36         0       1      Holverson, Mr. Alexander Oskar
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 61            62         1       1                 Icard, Miss. Amelie
# ..           ...       ...     ...                                 ...
# 842          843         1       1             Serepeca, Miss. Augusta
# 845          846         0       3                 Abbing, Mr. Anthony
# 866          867         1       2        Duran y More, Miss. Asuncion
# 875          876         1       3    Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3       Gustafsson, Mr. Alfred Ossian
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked  \
# ...

# %%
titanic[titanic["Firstname"].str.endswith("e")]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 16            17         0       3                      Rice, Master. Eugene
# 17            18         1       2              Williams, Mr. Charles Eugene
# 21            22         1       2                     Beesley, Mr. Lawrence
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 61            62         1       1                       Icard, Miss. Amelie
# ..           ...       ...     ...                                       ...
# 822          823         0       1           Reuchlin, Jonkheer. John George
# 827          828         1       2                     Mallet, Master. Andre
# 834          835         0       3                    Allum, Mr. Owen George
# 837          838         0       3                       Sirota, Mr. Maurice
# 839          840         1       1                      Marechal, Mr. Pierre
#
# ...

# %%
#search john in both case
titanic[titanic["Firstname"].str.contains("john",case = False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# ...

# %%
#find last name  in start and end both are in vovels
titanic[titanic["LastName"].str.contains("^[aeiouAEIOU].+[aeiouAEIOU]$")]
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 49            50         0       3
# 207          208         1       3
# 210          211         0       3
# 353          354         0       3
# 493          494         0       1
# 518          519         1       2
# 784          785         0       3
# 840          841         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 207                        Albimona, Mr. Nassef Cassem    male  26.0      0
# 210                                     Ali, Mr. Ahmed    male  24.0      0
# 353                          Arnold-Franchi, Mr. Josef    male  25.0      1
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# ...

# %%
# find last name in first and last char are not included vovels
titanic[titanic["LastName"].str.contains("^[^aeiouAEIOU].+[^aeiouAEIOU]$")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 884          885         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # TimeStamp Object

# %%
#create timestamp object

pd.Timestamp("2023/10/16")
# Out:
# Timestamp('2023-10-16 00:00:00')

# %%
pd.Timestamp("16th October 2023")
# Out:
# Timestamp('2023-10-16 00:00:00')

# %%
#providing time also

pd.Timestamp("2023/10/16, 2:14P.m ")
# Out:
# Timestamp('2023-10-16 14:14:00')

# %% [markdown]
# #Daterange function

# %%
pd.date_range(start="2022/10/15",end="2023/10/30",freq="2D")
# Out:
# DatetimeIndex(['2022-10-15', '2022-10-17', '2022-10-19', '2022-10-21',
#                '2022-10-23', '2022-10-25', '2022-10-27', '2022-10-29',
#                '2022-10-31', '2022-11-02',
#                ...
#                '2023-10-12', '2023-10-14', '2023-10-16', '2023-10-18',
#                '2023-10-20', '2023-10-22', '2023-10-24', '2023-10-26',
#                '2023-10-28', '2023-10-30'],
#               dtype='datetime64[ns]', length=191, freq='2D')

# %%
pd.date_range(start="2023/10/15",end="2023/10/30",freq="B")
# Out:
# DatetimeIndex(['2023-10-16', '2023-10-17', '2023-10-18', '2023-10-19',
#                '2023-10-20', '2023-10-23', '2023-10-24', '2023-10-25',
#                '2023-10-26', '2023-10-27', '2023-10-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start="2022/10/15",end="2023/10/30",freq="W")
# Out:
# DatetimeIndex(['2022-10-16', '2022-10-23', '2022-10-30', '2022-11-06',
#                '2022-11-13', '2022-11-20', '2022-11-27', '2022-12-04',
#                '2022-12-11', '2022-12-18', '2022-12-25', '2023-01-01',
#                '2023-01-08', '2023-01-15', '2023-01-22', '2023-01-29',
#                '2023-02-05', '2023-02-12', '2023-02-19', '2023-02-26',
#                '2023-03-05', '2023-03-12', '2023-03-19', '2023-03-26',
#                '2023-04-02', '2023-04-09', '2023-04-16', '2023-04-23',
#                '2023-04-30', '2023-05-07', '2023-05-14', '2023-05-21',
#                '2023-05-28', '2023-06-04', '2023-06-11', '2023-06-18',
#                '2023-06-25', '2023-07-02', '2023-07-09', '2023-07-16',
#                '2023-07-23', '2023-07-30', '2023-08-06', '2023-08-13',
#                '2023-08-20', '2023-08-27', '2023-09-03', '2023-09-10',
#                '2023-09-17', '2023-09-24', '2023-10-01', '2023-10-08',
# ...

# %%
d = pd.Series(["2023/10/15","2022/10/15","2021/10/15","2020/10/15"])
d
# Out:
# 0    2023/10/15
# 1    2022/10/15
# 2    2021/10/15
# 3    2020/10/15
# dtype: object

# %%
pd.to_datetime(d).dt.day
pd.to_datetime(d).dt.month
pd.to_datetime(d).dt.month_name()
pd.to_datetime(d).dt.day_name()
pd.to_datetime(d).dt.year
# Out:
# 0    2023
# 1    2022
# 2    2021
# 3    2020
# dtype: int32

# %%
df = pd.read_csv("D:\\excel data\\expense_data.csv")

# %%
df.head(5)
# Out:
#                Date               Account        Category  Subcategory  \
# 0  03/02/2022 10:11  CUB - online payment            Food          NaN
# 1  03/02/2022 10:11  CUB - online payment           Other          NaN
# 2  03/01/2022 19:50  CUB - online payment            Food          NaN
# 3  03/01/2022 18:56  CUB - online payment  Transportation          NaN
# 4  03/01/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
df["Date"].dt.year
df["Date"].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 272    11
# 273    11
# 274    11
# 275    11
# 276    11
# Name: Date, Length: 277, dtype: int32

# %%
df["Date"].dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: object

# %%
plt.plot(df["Date"],df["INR"])
plt.show()

# %%
df["day_name"] = df["Date"].dt.day_name()

# %%
df.head(5)
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
plt.plot(df["day_name"],df["INR"])

# %%
df.groupby("day_name")["INR"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='day_name'>

# %%
plt.bar(df["day_name"],df["INR"])
plt.show()

# %%
df["month_day"] = df["Date"].dt.month_name()

# %%
plt.bar(df["month_day"],df["INR"])
plt.show()

# %%
df.groupby("month_day")["INR"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='month_day'>

# %%
# question : Determine the day of the week when the restaurant received the highest total tips.

df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby("day")["tip"].sum()
# Out:
# day
# Thur    171.83
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Name: tip, dtype: float64
