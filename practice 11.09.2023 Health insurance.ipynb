# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("D:\\excel data\\Healthinsurance.csv")

# %%
df.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 332    61  female  31.160         0     no  northwest  13429.03540
# 1195   19  female  27.930         3     no  northwest  18838.70366
# 1037   45  female  30.495         1    yes  northwest  39725.51805
# 970    50  female  28.160         3     no  southeast  10702.64240
# 192    25    male  25.740         0     no  southeast   2137.65360

# %%
sns.scatterplot(x= df["region"],y = df["age"], hue = df["sex"],style = df["smoker"])

#sns.scatterplot(x = tips["total_bill"],y = tips["tip"], hue = tips["smoker"],style = tips["sex"])
# Out:
# <Axes: xlabel='region', ylabel='age'>

# %%
sns.histplot(df["region"])
# Out:
# <Axes: xlabel='region', ylabel='Count'>

# %%
#sns.countplot(x= df["children"],y = df["region"])

# %%
df["sex"] = df["sex"].replace({"male" : 0, "female" : 1})
df["smoker"] = df["smoker"].replace({"yes" :1, "no" : 0})

# %%
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df.drop("charges",axis = 1),df["charges"],test_size = 0.3,random_state = 0)

# %%
x_train.shape
# Out:
# (936, 6)

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker     region
# 1163   18    1  28.215         0       0  northeast
# 196    39    1  32.800         0       0  southwest
# 438    52    1  46.750         5       0  southeast
# 183    44    1  26.410         0       0  northwest
# 1298   33    0  27.455         2       0  northwest
# ...   ...  ...     ...       ...     ...        ...
# 763    27    0  26.030         0       0  northeast
# 835    42    0  35.970         2       0  southeast
# 1216   40    0  25.080         0       0  southeast
# 559    19    0  35.530         0       0  northwest
# 684    33    1  18.500         1       0  southwest
#
# [936 rows x 6 columns]

# %%
x_test
# Out:
#       age  sex     bmi  children  smoker     region
# 578    52    0  30.200         1       0  southwest
# 610    47    1  29.370         1       0  southeast
# 569    48    0  40.565         2       1  northwest
# 1034   61    0  38.380         0       0  northwest
# 198    51    1  18.050         0       0  northwest
# ...   ...  ...     ...       ...     ...        ...
# 1261   28    0  37.100         1       0  southwest
# 494    21    0  25.700         4       1  southwest
# 97     55    0  38.280         0       0  southeast
# 418    64    0  39.160         1       0  southeast
# 920    62    1  25.000         0       0  southwest
#
# [402 rows x 6 columns]

# %%
y_train
# Out:
# 1163     2200.83085
# 196      5649.71500
# 438     12592.53450
# 183      7419.47790
# 1298     5261.46945
#            ...
# 763      3070.80870
# 835      7160.33030
# 1216     5415.66120
# 559      1646.42970
# 684      4766.02200
# Name: charges, Length: 936, dtype: float64

# %%
y_test
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
#            ...
# 1261     3277.16100
# 494     17942.10600
# 97      10226.28420
# 418     14418.28040
# 920     13451.12200
# Name: charges, Length: 402, dtype: float64

# %%
y_train.shape
# Out:
# (936,)

# %%
y_test.shape
# Out:
# (402,)

# %%
x_test.shape
# Out:
# (402, 6)
