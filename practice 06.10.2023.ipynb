# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Fake news data1702.csv")

# %%
df
# Out:
#                                           event_category            city  \
# 0                         Yes, I have heard of fake news         Chicago
# 1                         Yes, I have heard of fake news       (not set)
# 2                         Yes, I have heard of fake news          Dallas
# 3                    Yes, I'm good at spotting fake news         Chicago
# 4                         Yes, I have heard of fake news        New York
# ...                                                  ...             ...
# 34316  Yes, think I could tell if an article was tell...         Wyoming
# 34317  Yes, think I could tell if an article was tell...      Wyomissing
# 34318  Yes, think I could tell if an article was tell...        Yarmouth
# 34319  Yes, think I could tell if an article was tell...  Yosemite Lakes
# 34320  Yes, think I could tell if an article was tell...            Zion
#
#        total_events
# 0               926
# 1               797
# 2               702
# ...
