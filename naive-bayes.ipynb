# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/kaggle/input/play-tennis-data/play_tennis.csv")

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No
# 14  D15     Sunny   Hot     High    Weak   No
# 15  D16     Sunny   Hot     High  Strong   No
# 16  D17  Overcast   Hot     High    Weak  Yes
# 17  D18      Rain  Mild     High    Weak  Yes
# 18  D19      Rain  Cool   Normal    Weak  Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   day       28 non-null     object
#  1   outlook   28 non-null     object
#  2   temp      28 non-null     object
#  3   humidity  28 non-null     object
#  4   wind      28 non-null     object
#  5   play      28 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#        day outlook  temp humidity  wind play
# count   28      28    28       28    28   28
# unique  28       3     3        2     2    2
# top     D1   Sunny  Mild     High  Weak  Yes
# freq     1      10    12       14    16   18

# %%
df.isnull().sum()
# Out:
# day         0
# outlook     0
# temp        0
# humidity    0
# wind        0
# play        0
# dtype: int64

# %%
df.drop(["day"],axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['outlook', 'temp', 'humidity', 'wind', 'play'], dtype='object')

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# le = LabelEncoder()

# %%
# df["outlook"] = le.fit_transform(df["outlook"])

# %%
# df["temp"] = le.fit_transform(df["temp"])

# %%
# df["humidity"] = le.fit_transform(df["humidity"])
# df["wind"] = le.fit_transform(df["wind"])
# df["play"] = le.fit_transform(df["play"])

# %%
# x = df.drop(["play"],axis = 1)
# y = df["play"]

# %%
# from sklearn.model_selection import train_test_split

# %%
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 1)

# %%
# x_train.shape,x_test.shape

# %%
# y_train.shape,y_test.shape

# %%
# df["outlook"].value_counts()
df.columns
# Out:
# Index(['outlook', 'temp', 'humidity', 'wind', 'play'], dtype='object')

# %%
df["outlook"].value_counts()
# Out:
# outlook
# Sunny       10
# Rain        10
# Overcast     8
# Name: count, dtype: int64

# %%
df["temp"].value_counts()
# Out:
# temp
# Mild    12
# Hot      8
# Cool     8
# Name: count, dtype: int64

# %%
df["humidity"].value_counts()
# Out:
# humidity
# High      14
# Normal    14
# Name: count, dtype: int64

# %%
df["wind"].value_counts()
# Out:
# wind
# Weak      16
# Strong    12
# Name: count, dtype: int64

# %%
df["play"].value_counts()
# Out:
# play
# Yes    18
# No     10
# Name: count, dtype: int64

# %%
p_yes = 18/28
p_no = 10/28

# %%
print(p_yes)
print(p_no)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %%
# outlook

pd.crosstab(df["outlook"],df["play"])
# Out:
# play      No  Yes
# outlook
# Overcast   0    8
# Rain       4    6
# Sunny      6    4

# %%
prob_overcast_no = 0
prob_rain_no = 4/10
prob_sunny_no = 6/10


prob_overcast_yes = 8/18
prob_rain_yes = 6/18
prob_sunny_yes = 4/18

# %%
# temp

pd.crosstab(df["temp"],df["play"])
# Out:
# play  No  Yes
# temp
# Cool   2    6
# Hot    4    4
# Mild   4    8

# %%
prob_cool_no = 2/10
prob_hot_no = 4/10
prob_mild_no = 4/10


prob_cool_yes = 6/18
prob_hot_yes = 4/18
prob_mild_yes = 8/18

# %%
# humidity

pd.crosstab(df["humidity"],df["play"])
# Out:
# play      No  Yes
# humidity
# High       8    6
# Normal     2   12

# %%
prob_high_no = 8/10
prob_normal_no = 2/10


prob_high_yes = 6/18
prob_normal_yes = 12/18

# %%
# wind

pd.crosstab(df["wind"],df["play"])
# Out:
# play    No  Yes
# wind
# Strong   6    6
# Weak     4   12

# %%
prob_strong_no = 6/10
prob_weak_no = 4/10


prob_strong_yes = 6/18
prob_weak_yes = 12/18

# %%
# outlook = sunny, temp = hot, humidity = high, wind = weak

prob_yes = p_yes*prob_sunny_yes*prob_hot_yes*prob_high_yes*prob_weak_yes
print(prob_yes)
# Out:
# 0.007054673721340388

# %%
prob_no =p_no*prob_sunny_no*prob_hot_no*prob_high_no*prob_weak_no
print(prob_no)
# Out:
# 0.02742857142857143
