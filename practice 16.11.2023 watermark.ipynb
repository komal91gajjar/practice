# %%
from PIL import Image
import os
def create_text_files(folder_path,dest_path):
    img_info="0 0.062438 0.477730 0.078047 0.050287"
    # Ensure the folder path ends with a slash
    if not folder_path.endswith('/'):
        folder_path += '/'
    # Get a list of all files in the folder
    files = os.listdir(folder_path)
    # Iterate through each file in the folder
    for file in files:
        # Check if the file is an image (you can customize the extensions)
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Create a text file with the same name as the image
            text_file_path = dest_path +'/'+ os.path.splitext(file)[0] + '.txt'
            # Write image information to the text file
            with open(text_file_path, 'w') as text_file:
                text_file.write(img_info)
            print(f"Text file '{text_file_path}' created.")
if __name__ == "__main__":
    # Replace 'your_folder_path' with the actual path to your image folder
    folder_path = 'Left_center'
    dest_path = "left_center_txt"
    # Call the function to create text files
    create_text_files(folder_path,dest_path)
# Out:
# Text file 'left_center_txt/frame_0000.txt' created.
# Text file 'left_center_txt/frame_0000_13.txt' created.
# Text file 'left_center_txt/frame_0000_19.txt' created.
# Text file 'left_center_txt/frame_0000_20.txt' created.
# Text file 'left_center_txt/frame_0000_21.txt' created.
# Text file 'left_center_txt/frame_0000_22.txt' created.
# Text file 'left_center_txt/frame_0000_24.txt' created.
# Text file 'left_center_txt/frame_0000_26.txt' created.
# Text file 'left_center_txt/frame_0000_28.txt' created.
# Text file 'left_center_txt/frame_0000_3.txt' created.
# Text file 'left_center_txt/frame_0000_34.txt' created.
# Text file 'left_center_txt/frame_0000_35.txt' created.
# Text file 'left_center_txt/frame_0000_37.txt' created.
# Text file 'left_center_txt/frame_0000_40.txt' created.
# Text file 'left_center_txt/frame_0000_44.txt' created.
# Text file 'left_center_txt/frame_0000_46.txt' created.
# Text file 'left_center_txt/frame_0000_5.txt' created.
# Text file 'left_center_txt/frame_0000_52.txt' created.
# Text file 'left_center_txt/frame_0000_58.txt' created.
# Text file 'left_center_txt/frame_0000_67.txt' created.
# Text file 'left_center_txt/frame_0000_68.txt' created.
# Text file 'left_center_txt/frame_0000_7.txt' created.
# Text file 'left_center_txt/frame_0000_71.txt' created.
# Text file 'left_center_txt/frame_0000_72.txt' created.
# Text file 'left_center_txt/frame_0000_75.txt' created.
# Text file 'left_center_txt/frame_0000_84.txt' created.
# Text file 'left_center_txt/frame_0000_86.txt' created.
# Text file 'left_center_txt/frame_0004.txt' created.
# Text file 'left_center_txt/frame_0006.txt' created.
# Text file 'left_center_txt/frame_0010.txt' created.
# Text file 'left_center_txt/frame_0011.txt' created.
# Text file 'left_center_txt/frame_0014.txt' created.
# Text file 'left_center_txt/frame_0015.txt' created.
# Text file 'left_center_txt/frame_0019.txt' created.
# Text file 'left_center_txt/frame_0020.txt' created.
# Text file 'left_center_txt/frame_0020_11.txt' created.
# Text file 'left_center_txt/frame_0020_13.txt' created.
# Text file 'left_center_txt/frame_0020_18.txt' created.
# Text file 'left_center_txt/frame_0020_21.txt' created.
# Text file 'left_center_txt/frame_0020_22.txt' created.
# Text file 'left_center_txt/frame_0020_35.txt' created.
# Text file 'left_center_txt/frame_0020_43.txt' created.
# Text file 'left_center_txt/frame_0020_44.txt' created.
# Text file 'left_center_txt/frame_0020_5.txt' created.
# Text file 'left_center_txt/frame_0020_52.txt' created.
# Text file 'left_center_txt/frame_0020_54.txt' created.
# Text file 'left_center_txt/frame_0020_55.txt' created.
# Text file 'left_center_txt/frame_0020_58.txt' created.
# Text file 'left_center_txt/frame_0020_6.txt' created.
# Text file 'left_center_txt/frame_0020_61.txt' created.
# Text file 'left_center_txt/frame_0020_63.txt' created.
# Text file 'left_center_txt/frame_0020_64.txt' created.
# Text file 'left_center_txt/frame_0020_68.txt' created.
# Text file 'left_center_txt/frame_0020_69.txt' created.
# Text file 'left_center_txt/frame_0020_70.txt' created.
# Text file 'left_center_txt/frame_0020_71.txt' created.
# Text file 'left_center_txt/frame_0020_73.txt' created.
# Text file 'left_center_txt/frame_0020_81.txt' created.
# Text file 'left_center_txt/frame_0020_82.txt' created.
# Text file 'left_center_txt/frame_0020_83.txt' created.
# Text file 'left_center_txt/frame_0020_84.txt' created.
# Text file 'left_center_txt/frame_0020_85.txt' created.
# Text file 'left_center_txt/frame_0020_89.txt' created.
# Text file 'left_center_txt/frame_0021.txt' created.
# Text file 'left_center_txt/frame_0024.txt' created.
# Text file 'left_center_txt/frame_0029.txt' created.
# Text file 'left_center_txt/frame_0030.txt' created.
# Text file 'left_center_txt/frame_0031.txt' created.
# Text file 'left_center_txt/frame_0032.txt' created.
# Text file 'left_center_txt/frame_0039.txt' created.
# Text file 'left_center_txt/frame_0040.txt' created.
# Text file 'left_center_txt/frame_0040_17.txt' created.
# Text file 'left_center_txt/frame_0040_18.txt' created.
# Text file 'left_center_txt/frame_0040_23.txt' created.
# Text file 'left_center_txt/frame_0040_34.txt' created.
# Text file 'left_center_txt/frame_0040_39.txt' created.
# Text file 'left_center_txt/frame_0040_4.txt' created.
# Text file 'left_center_txt/frame_0040_41.txt' created.
# Text file 'left_center_txt/frame_0040_45.txt' created.
# Text file 'left_center_txt/frame_0040_46.txt' created.
# Text file 'left_center_txt/frame_0040_5.txt' created.
# Text file 'left_center_txt/frame_0040_68.txt' created.
# Text file 'left_center_txt/frame_0040_73.txt' created.
# Text file 'left_center_txt/frame_0040_79.txt' created.
# Text file 'left_center_txt/frame_0040_88.txt' created.
# Text file 'left_center_txt/frame_0040_89.txt' created.
# Text file 'left_center_txt/frame_0041.txt' created.
# Text file 'left_center_txt/frame_0043.txt' created.
# Text file 'left_center_txt/frame_0046.txt' created.
# Text file 'left_center_txt/frame_0048.txt' created.
# Text file 'left_center_txt/frame_0049.txt' created.
# Text file 'left_center_txt/frame_0050.txt' created.
# Text file 'left_center_txt/frame_0052.txt' created.
# Text file 'left_center_txt/frame_0053.txt' created.
# Text file 'left_center_txt/frame_0054.txt' created.
# Text file 'left_center_txt/frame_0055.txt' created.
# Text file 'left_center_txt/frame_0058.txt' created.
# Text file 'left_center_txt/frame_0059.txt' created.
# Text file 'left_center_txt/frame_0060_10.txt' created.
# Text file 'left_center_txt/frame_0060_16.txt' created.
# Text file 'left_center_txt/frame_0060_17.txt' created.
# Text file 'left_center_txt/frame_0060_24.txt' created.
# Text file 'left_center_txt/frame_0060_27.txt' created.
# Text file 'left_center_txt/frame_0060_3.txt' created.
# Text file 'left_center_txt/frame_0060_31.txt' created.
# Text file 'left_center_txt/frame_0060_34.txt' created.
# Text file 'left_center_txt/frame_0060_4.txt' created.
# Text file 'left_center_txt/frame_0060_40.txt' created.
# Text file 'left_center_txt/frame_0060_44.txt' created.
# Text file 'left_center_txt/frame_0060_51.txt' created.
# Text file 'left_center_txt/frame_0060_56.txt' created.
# Text file 'left_center_txt/frame_0060_6.txt' created.
# Text file 'left_center_txt/frame_0060_63.txt' created.
# Text file 'left_center_txt/frame_0060_65.txt' created.
# Text file 'left_center_txt/frame_0060_67.txt' created.
# Text file 'left_center_txt/frame_0060_69.txt' created.
# Text file 'left_center_txt/frame_0060_70.txt' created.
# Text file 'left_center_txt/frame_0060_72.txt' created.
# Text file 'left_center_txt/frame_0060_76.txt' created.
# Text file 'left_center_txt/frame_0060_79.txt' created.
# Text file 'left_center_txt/frame_0060_82.txt' created.
# Text file 'left_center_txt/frame_0060_83.txt' created.
# Text file 'left_center_txt/frame_0060_84.txt' created.
# Text file 'left_center_txt/frame_0061.txt' created.
# Text file 'left_center_txt/frame_0062.txt' created.
# Text file 'left_center_txt/frame_0068.txt' created.
# Text file 'left_center_txt/frame_0073.txt' created.
# Text file 'left_center_txt/frame_0075.txt' created.
# Text file 'left_center_txt/frame_0078.txt' created.
# Text file 'left_center_txt/frame_0079.txt' created.
# Text file 'left_center_txt/frame_0080.txt' created.
# Text file 'left_center_txt/frame_0080_20.txt' created.
# Text file 'left_center_txt/frame_0080_22.txt' created.
# Text file 'left_center_txt/frame_0080_23.txt' created.
# Text file 'left_center_txt/frame_0080_26.txt' created.
# Text file 'left_center_txt/frame_0080_30.txt' created.
# Text file 'left_center_txt/frame_0080_36.txt' created.
# Text file 'left_center_txt/frame_0080_37.txt' created.
# Text file 'left_center_txt/frame_0080_4.txt' created.
# Text file 'left_center_txt/frame_0080_40.txt' created.
# Text file 'left_center_txt/frame_0080_46.txt' created.
# Text file 'left_center_txt/frame_0080_48.txt' created.
# Text file 'left_center_txt/frame_0080_59.txt' created.
# Text file 'left_center_txt/frame_0080_6.txt' created.
# Text file 'left_center_txt/frame_0080_61.txt' created.
# Text file 'left_center_txt/frame_0080_8.txt' created.
# Text file 'left_center_txt/frame_0080_81.txt' created.
# Text file 'left_center_txt/frame_0080_83.txt' created.
# Text file 'left_center_txt/frame_0100.txt' created.
# Text file 'left_center_txt/frame_0100_10.txt' created.
# Text file 'left_center_txt/frame_0100_11.txt' created.
# Text file 'left_center_txt/frame_0100_17.txt' created.
# Text file 'left_center_txt/frame_0100_29.txt' created.
# Text file 'left_center_txt/frame_0100_45.txt' created.
# Text file 'left_center_txt/frame_0100_46.txt' created.
# Text file 'left_center_txt/frame_0100_52.txt' created.
# Text file 'left_center_txt/frame_0100_56.txt' created.
# Text file 'left_center_txt/frame_0100_58.txt' created.
# Text file 'left_center_txt/frame_0100_61.txt' created.
# Text file 'left_center_txt/frame_0100_67.txt' created.
# Text file 'left_center_txt/frame_0100_69.txt' created.
# Text file 'left_center_txt/frame_0100_76.txt' created.
# Text file 'left_center_txt/frame_0100_81.txt' created.
# Text file 'left_center_txt/frame_0100_83.txt' created.
# Text file 'left_center_txt/frame_0100_86.txt' created.
# Text file 'left_center_txt/frame_0100_88.txt' created.
# Text file 'left_center_txt/frame_0103.txt' created.
# Text file 'left_center_txt/frame_0106.txt' created.
# Text file 'left_center_txt/frame_0108.txt' created.
# Text file 'left_center_txt/frame_0112.txt' created.
# Text file 'left_center_txt/frame_0116.txt' created.
# Text file 'left_center_txt/frame_0120_10.txt' created.
# Text file 'left_center_txt/frame_0120_12.txt' created.
# Text file 'left_center_txt/frame_0120_13.txt' created.
# Text file 'left_center_txt/frame_0120_20.txt' created.
# Text file 'left_center_txt/frame_0120_22.txt' created.
# Text file 'left_center_txt/frame_0120_23.txt' created.
# Text file 'left_center_txt/frame_0120_24.txt' created.
# Text file 'left_center_txt/frame_0120_27.txt' created.
# Text file 'left_center_txt/frame_0120_28.txt' created.
# Text file 'left_center_txt/frame_0120_29.txt' created.
# Text file 'left_center_txt/frame_0120_31.txt' created.
# Text file 'left_center_txt/frame_0120_34.txt' created.
# Text file 'left_center_txt/frame_0120_36.txt' created.
# Text file 'left_center_txt/frame_0120_39.txt' created.
# Text file 'left_center_txt/frame_0120_40.txt' created.
# Text file 'left_center_txt/frame_0120_41.txt' created.
# Text file 'left_center_txt/frame_0120_47.txt' created.
# Text file 'left_center_txt/frame_0120_51.txt' created.
# Text file 'left_center_txt/frame_0120_56.txt' created.
# Text file 'left_center_txt/frame_0120_58.txt' created.
# Text file 'left_center_txt/frame_0120_59.txt' created.
# Text file 'left_center_txt/frame_0120_6.txt' created.
# Text file 'left_center_txt/frame_0120_70.txt' created.
# Text file 'left_center_txt/frame_0120_73.txt' created.
# Text file 'left_center_txt/frame_0120_76.txt' created.
# Text file 'left_center_txt/frame_0120_79.txt' created.
# Text file 'left_center_txt/frame_0120_80.txt' created.
# Text file 'left_center_txt/frame_0124.txt' created.
# Text file 'left_center_txt/frame_0125.txt' created.
# Text file 'left_center_txt/frame_0127.txt' created.
# Text file 'left_center_txt/frame_0132.txt' created.
# Text file 'left_center_txt/frame_0133.txt' created.
# Text file 'left_center_txt/frame_0135.txt' created.
# Text file 'left_center_txt/frame_0140.txt' created.
# Text file 'left_center_txt/frame_0140_10.txt' created.
# Text file 'left_center_txt/frame_0140_11.txt' created.
# Text file 'left_center_txt/frame_0140_16.txt' created.
# Text file 'left_center_txt/frame_0140_22.txt' created.
# Text file 'left_center_txt/frame_0140_27.txt' created.
# Text file 'left_center_txt/frame_0140_29.txt' created.
# Text file 'left_center_txt/frame_0140_3.txt' created.
# Text file 'left_center_txt/frame_0140_34.txt' created.
# Text file 'left_center_txt/frame_0140_43.txt' created.
# Text file 'left_center_txt/frame_0140_44.txt' created.
# Text file 'left_center_txt/frame_0140_48.txt' created.
# Text file 'left_center_txt/frame_0140_5.txt' created.
# Text file 'left_center_txt/frame_0140_53.txt' created.
# Text file 'left_center_txt/frame_0140_58.txt' created.
# Text file 'left_center_txt/frame_0140_67.txt' created.
# Text file 'left_center_txt/frame_0140_69.txt' created.
# Text file 'left_center_txt/frame_0140_7.txt' created.
# Text file 'left_center_txt/frame_0140_70.txt' created.
# Text file 'left_center_txt/frame_0140_71.txt' created.
# Text file 'left_center_txt/frame_0140_80.txt' created.
# Text file 'left_center_txt/frame_0140_81.txt' created.
# Text file 'left_center_txt/frame_0140_82.txt' created.
# Text file 'left_center_txt/frame_0140_86.txt' created.
# Text file 'left_center_txt/frame_0140_88.txt' created.
# Text file 'left_center_txt/frame_0140_89.txt' created.
# Text file 'left_center_txt/frame_0160_54.txt' created.
# Text file 'left_center_txt/frame_0180_26.txt' created.
# Text file 'left_center_txt/frame_0180_34.txt' created.
# Text file 'left_center_txt/frame_0180_48.txt' created.
# Text file 'left_center_txt/frame_0200_24.txt' created.
# Text file 'left_center_txt/frame_0200_33.txt' created.
# Text file 'left_center_txt/frame_0200_42.txt' created.
# Text file 'left_center_txt/frame_0200_45.txt' created.
# Text file 'left_center_txt/frame_0200_48.txt' created.
# Text file 'left_center_txt/frame_0220_18.txt' created.
# Text file 'left_center_txt/frame_0220_31.txt' created.
# Text file 'left_center_txt/frame_0240_31.txt' created.
# Text file 'left_center_txt/frame_0240_7.txt' created.
# Text file 'left_center_txt/frame_0260_29.txt' created.
# Text file 'left_center_txt/frame_0280_17.txt' created.
# Text file 'left_center_txt/frame_0280_18.txt' created.
# Text file 'left_center_txt/frame_0280_22.txt' created.
# Text file 'left_center_txt/frame_0280_31.txt' created.
# Text file 'left_center_txt/frame_0280_5.txt' created.
# Text file 'left_center_txt/frame_0320_29.txt' created.
# Text file 'left_center_txt/frame_0360_24.txt' created.
# Text file 'left_center_txt/frame_0380_21.txt' created.

# %%
from PIL import Image
import os
def create_text_files(folder_path,dest_path):
    img_info="0 0.066203 0.036466 0.070721 0.046411"
    # Ensure the folder path ends with a slash
    if not folder_path.endswith('/'):
        folder_path += '/'
    # Get a list of all files in the folder
    files = os.listdir(folder_path)
    # Iterate through each file in the folder
    for file in files:
        # Check if the file is an image (you can customize the extensions)
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Create a text file with the same name as the image
            text_file_path = dest_path +'/'+ os.path.splitext(file)[0] + '.txt'
            # Write image information to the text file
            with open(text_file_path, 'w') as text_file:
                text_file.write(img_info)
            print(f"Text file '{text_file_path}' created.")
if __name__ == "__main__":
    # Replace 'your_folder_path' with the actual path to your image folder
    folder_path = 'Misc'
    dest_path = "Misc\Misc_txt"
    # Call the function to create text files
    create_text_files(folder_path,dest_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\visual studio data\practice 16.11.2023 watermark.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a> dest_path = "Misc\Misc_txt"
#      <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> # Call the function to create text files
# ---> <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a> create_text_files(folder_path,dest_path)
#
# d:\visual studio data\practice 16.11.2023 watermark.ipynb Cell 2 line 9
#       <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     folder_path += '/'
#       <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> # Get a list of all files in the folder
# ----> <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> files = os.listdir(folder_path)
#      <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> # Iterate through each file in the folder
#      <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> for file in files:
#      <a href='vscode-notebook-cell:/d%3A/visual%20studio%20data/practice%2016.11.2023%20watermark.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     # Check if the file is an image (you can customize the extensions)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Misc/'
