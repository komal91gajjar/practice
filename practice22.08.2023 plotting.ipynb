# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.plot()
plt.show()

# %% [markdown]
# # scatterplot

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories') # scatter plot draw
#df.plot() #
plt.show()

# %%
df.plot(kind = "scatter", x = "Duration", y = "Maxpulse")
plt.show()

# %% [markdown]
# # histogram

# %%
#df.plot(kind = "hist", x = "Duration", y = "Maxpulse")


df["Duration"].plot(kind = 'hist')
plt.show()
#df["Duration"].plot(kind = "hist")

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print(matplotlib.__version__)
# Out:
# 3.5.1

# %%
xpoints = np.array([1,10])
ypoints = np.array([20,50])

plt.plot(xpoints,ypoints)

plt.show()

# %%
xpoints = np.array([1, 8, 15,20])
ypoints = np.array([3, 10, 20,30])

plt.plot(xpoints, ypoints, "o")
plt.show()

# %%
xpoints = np.array([1, 8, 15,20])
ypoints = np.array([3, 10, 20,30])

plt.plot(xpoints, ypoints, "*")
plt.show()

# %%
xpoints = np.array([1, 8, 15,20])
ypoints = np.array([3, 10, 20,30])

plt.plot(xpoints, ypoints, 0)
plt.show()

# %%
xpoints = np.array([5,15,30])
plt.plot(xpoints)
plt.show()

# %%
plt.plot(xpoints, marker = "o")
plt.show()

# %% [markdown]
# # marker refrence

# %%
plt.plot(xpoints, marker = "o")
plt.show()

# %%
apoints = np.array([1,5])
bpoints = np.array([10,15])

plt.plot(apoints,bpoints, marker = "o")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = "*")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = ".")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = ",")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = "x")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = "X")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = "+")
plt.show()

# %%
plt.plot(apoints,bpoints, marker = "p")
plt.show()

# %% [markdown]
# # line refrence

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '+:y')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '+-')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '+:')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '+--')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '+-.')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '+:c')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

#plt.plot(ypoints, '+:r')
#plt.show()

#plt.plot(ypoints, '+:b')
#plt.show()

#plt.plot(ypoints, '+:g')
#plt.show()

plt.plot(ypoints, '+:m')
plt.show()

# %%
plt.plot(ypoints, '+:r' , ms = 30)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '+', ms = 25, mec = 'y')
plt.show()
