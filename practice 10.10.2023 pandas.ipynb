# %%
# import some useful library

import numpy as np
import pandas as pd

# %%
# read file

df = pd.read_csv("D:\\excel data\\countryContinent.csv", encoding='latin-1')

# %%
# all the data load in file

df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
#           sub_region  region_code  sub_region_code
# ...

# %%
# dataframe in shape
df.shape
# Out:
# (249, 9)

# %%
#dataframe types
df.dtypes
# Out:
# country             object
# code_2              object
# code_3              object
# country_code         int64
# iso_3166_2          object
# continent           object
# sub_region          object
# region_code        float64
# sub_region_code    float64
# dtype: object

# %%
#dataframe index
df.index
# Out:
# RangeIndex(start=0, stop=249, step=1)

# %%
#dataframe in columns
df.columns
# Out:
# Index(['country', 'code_2', 'code_3', 'country_code', 'iso_3166_2',
#        'continent', 'sub_region', 'region_code', 'sub_region_code'],
#       dtype='object')

# %%
#dataframe in top data load using head()
df.head(2)
# Out:
#          country code_2 code_3  country_code     iso_3166_2 continent  \
# 0    Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1  Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0

# %%
#dataframe in last data load using tail()
df.tail(5)
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
#           sub_region  region_code  sub_region_code
# 244        Polynesia          9.0             61.0
# 245  Northern Africa          2.0             15.0
# 246     Western Asia        142.0            145.0
# 247   Eastern Africa          2.0             14.0
# 248   Eastern Africa          2.0             14.0

# %%
#dataframe all information using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          249 non-null    object
#  1   code_2           248 non-null    object
#  2   code_3           249 non-null    object
#  3   country_code     249 non-null    int64
#  4   iso_3166_2       249 non-null    object
#  5   continent        240 non-null    object
#  6   sub_region       240 non-null    object
#  7   region_code      240 non-null    float64
#  8   sub_region_code  240 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 17.6+ KB

# %%
#dataframe in all numeric columns describe using describe()
df.describe()
# Out:
#        country_code  region_code  sub_region_code
# count    249.000000   240.000000        240.00000
# mean     433.835341    67.825000         56.63750
# std      252.980446    67.654075         54.58537
# min        4.000000     2.000000          5.00000
# 25%      218.000000     9.000000         15.00000
# 50%      434.000000    19.000000         30.00000
# 75%      652.000000   142.000000         61.00000
# max      894.000000   150.000000        155.00000

# %%
#dataframe value find using value
df.values
# Out:
# array([['Afghanistan', 'AF', 'AFG', ..., 'Southern Asia', 142.0, 34.0],
#        ['Åland Islands', 'AX', 'ALA', ..., 'Northern Europe', 150.0,
#         154.0],
#        ['Albania', 'AL', 'ALB', ..., 'Southern Europe', 150.0, 39.0],
#        ...,
#        ['Yemen', 'YE', 'YEM', ..., 'Western Asia', 142.0, 145.0],
#        ['Zambia', 'ZM', 'ZMB', ..., 'Eastern Africa', 2.0, 14.0],
#        ['Zimbabwe', 'ZW', 'ZWE', ..., 'Eastern Africa', 2.0, 14.0]],
#       dtype=object)

# %%
df.sample(5)
# Out:
#                       country code_2 code_3  country_code     iso_3166_2  \
# 165                    Norway     NO    NOR           578  ISO 3166-2:NO
# 213                 Swaziland     SZ    SWZ           748  ISO 3166-2:SZ
# 16                    Bahamas     BS    BHS            44  ISO 3166-2:BS
# 242  Virgin Islands (British)     VG    VGB            92  ISO 3166-2:VG
# 7                    Anguilla     AI    AIA           660  ISO 3166-2:AI
#
#     continent       sub_region  region_code  sub_region_code
# 165    Europe  Northern Europe        150.0            154.0
# 213    Africa  Southern Africa          2.0             18.0
# 16   Americas        Caribbean         19.0             29.0
# 242  Americas        Caribbean         19.0             29.0
# 7    Americas        Caribbean         19.0             29.0

# %%
#dataframe in null value or not is find using isnull()
df.isnull().sum()
# Out:
# country            0
# code_2             1
# code_3             0
# country_code       0
# iso_3166_2         0
# continent          9
# sub_region         9
# region_code        9
# sub_region_code    9
# dtype: int64

# %%
#dataframe in duplicate value exist or not using duplicated()
df.duplicated().sum()
# Out:
# 0

# %%
#dataframe in null value or not is find using notnull()
df.notnull().sum()
# Out:
# country            249
# code_2             248
# code_3             249
# country_code       249
# iso_3166_2         249
# continent          240
# sub_region         240
# region_code        240
# sub_region_code    240
# dtype: int64

# %%
#dataframe in rename column name using rename()
df.rename(columns={"country":"country_name"})
# Out:
#           country_name code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
#           sub_region  region_code  sub_region_code
# ...

# %%
#dataframe in single column data load
df["country"]
# Out:
# 0            Afghanistan
# 1          Åland Islands
# 2                Albania
# 3                Algeria
# 4         American Samoa
#              ...
# 244    Wallis and Futuna
# 245       Western Sahara
# 246                Yemen
# 247               Zambia
# 248             Zimbabwe
# Name: country, Length: 249, dtype: object

# %%
#dataframe in multipal column data load
df[["country","country_code","sub_region"]]
# Out:
#                country  country_code       sub_region
# 0          Afghanistan             4    Southern Asia
# 1        Åland Islands           248  Northern Europe
# 2              Albania             8  Southern Europe
# 3              Algeria            12  Northern Africa
# 4       American Samoa            16        Polynesia
# ..                 ...           ...              ...
# 244  Wallis and Futuna           876        Polynesia
# 245     Western Sahara           732  Northern Africa
# 246              Yemen           887     Western Asia
# 247             Zambia           894   Eastern Africa
# 248           Zimbabwe           716   Eastern Africa
#
# [249 rows x 3 columns]

# %%
# single row fetch using iloc
df.iloc[0]
# Out:
# country              Afghanistan
# code_2                        AF
# code_3                       AFG
# country_code                   4
# iso_3166_2         ISO 3166-2:AF
# continent                   Asia
# sub_region         Southern Asia
# region_code                142.0
# sub_region_code             34.0
# Name: 0, dtype: object

# %%
# multipal row fetch using iloc
df.iloc[0:4]
# Out:
#          country code_2 code_3  country_code     iso_3166_2 continent  \
# 0    Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1  Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2        Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3        Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0
# 2  Southern Europe        150.0             39.0
# 3  Northern Africa          2.0             15.0

# %%
#fancy indexing
df.iloc[[0,4,9]]
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# 9  Antigua and Barbuda     AG    ATG            28  ISO 3166-2:AG  Americas
#
#       sub_region  region_code  sub_region_code
# 0  Southern Asia        142.0             34.0
# 4      Polynesia          9.0             61.0
# 9      Caribbean         19.0             29.0

# %%
df.set_index("country",inplace=True)

# %%
df.reset_index("country",inplace=True)

# %%
#single row data detch (label) using loc
df.loc["Algeria"]
# Out:
# code_2                          DZ
# code_3                         DZA
# country_code                    12
# iso_3166_2           ISO 3166-2:DZ
# continent                   Africa
# sub_region         Northern Africa
# region_code                    2.0
# sub_region_code               15.0
# Name: Algeria, dtype: object

# %%
#select row and column both data fetch
df.iloc[0:4,0:7]
# Out:
#          country code_2 code_3  country_code     iso_3166_2 continent  \
# 0    Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1  Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2        Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3        Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
#
#         sub_region
# 0    Southern Asia
# 1  Northern Europe
# 2  Southern Europe
# 3  Northern Africa

# %%
# filtering data
# find out in data how many continent in asia and sub_region southern asia
mask = df["continent"] == "Asia"
df[mask]
# Out:
#                                      country code_2 code_3  country_code  \
# 0                                Afghanistan     AF    AFG             4
# 11                                   Armenia     AM    ARM            51
# 15                                Azerbaijan     AZ    AZE            31
# 17                                   Bahrain     BH    BHR            48
# 18                                Bangladesh     BD    BGD            50
# 25                                    Bhutan     BT    BTN            64
# 33                         Brunei Darussalam     BN    BRN            96
# 37                                  Cambodia     KH    KHM           116
# 45                                     China     CN    CHN           156
# 58                                    Cyprus     CY    CYP           196
# 81                                   Georgia     GE    GEO           268
# 99                                 Hong Kong     HK    HKG           344
# ...

# %%
new_df = df[mask]
new_df[["continent","sub_region"]]
# Out:
#     continent          sub_region
# 0        Asia       Southern Asia
# 11       Asia        Western Asia
# 15       Asia        Western Asia
# 17       Asia        Western Asia
# 18       Asia       Southern Asia
# 25       Asia       Southern Asia
# 33       Asia  South-Eastern Asia
# 37       Asia  South-Eastern Asia
# 45       Asia        Eastern Asia
# 58       Asia        Western Asia
# 81       Asia        Western Asia
# 99       Asia        Eastern Asia
# 102      Asia       Southern Asia
# 103      Asia  South-Eastern Asia
# 104      Asia       Southern Asia
# 105      Asia        Western Asia
# 108      Asia        Western Asia
# 111      Asia        Eastern Asia
# 113      Asia        Western Asia
# 114      Asia        Central Asia
# 117      Asia        Eastern Asia
# 118      Asia        Eastern Asia
# 119      Asia        Western Asia
# 120      Asia        Central Asia
# 121      Asia  South-Eastern Asia
# 123      Asia        Western Asia
# ...

# %%
df[df["continent"] == "Asia"][["continent","sub_region"]]
# Out:
#     continent          sub_region
# 0        Asia       Southern Asia
# 11       Asia        Western Asia
# 15       Asia        Western Asia
# 17       Asia        Western Asia
# 18       Asia       Southern Asia
# 25       Asia       Southern Asia
# 33       Asia  South-Eastern Asia
# 37       Asia  South-Eastern Asia
# 45       Asia        Eastern Asia
# 58       Asia        Western Asia
# 81       Asia        Western Asia
# 99       Asia        Eastern Asia
# 102      Asia       Southern Asia
# 103      Asia  South-Eastern Asia
# 104      Asia       Southern Asia
# 105      Asia        Western Asia
# 108      Asia        Western Asia
# 111      Asia        Eastern Asia
# 113      Asia        Western Asia
# 114      Asia        Central Asia
# 117      Asia        Eastern Asia
# 118      Asia        Eastern Asia
# 119      Asia        Western Asia
# 120      Asia        Central Asia
# 121      Asia  South-Eastern Asia
# 123      Asia        Western Asia
# ...

# %%
df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
#           sub_region  region_code  sub_region_code
# ...

# %%
#how to find sub region in southern asia

df[df["sub_region"] == "Southern Asia"]
# Out:
#                         country code_2 code_3  country_code     iso_3166_2  \
# 0                   Afghanistan     AF    AFG             4  ISO 3166-2:AF
# 18                   Bangladesh     BD    BGD            50  ISO 3166-2:BD
# 25                       Bhutan     BT    BTN            64  ISO 3166-2:BT
# 102                       India     IN    IND           356  ISO 3166-2:IN
# 104  Iran (Islamic Republic of)     IR    IRN           364  ISO 3166-2:IR
# 135                    Maldives     MV    MDV           462  ISO 3166-2:MV
# 155                       Nepal     NP    NPL           524  ISO 3166-2:NP
# 167                    Pakistan     PK    PAK           586  ISO 3166-2:PK
# 209                   Sri Lanka     LK    LKA           144  ISO 3166-2:LK
#
#     continent     sub_region  region_code  sub_region_code
# 0        Asia  Southern Asia        142.0             34.0
# 18       Asia  Southern Asia        142.0             34.0
# ...

# %%
df[df["sub_region"] == "Southern Asia"].shape
# Out:
# (9, 9)

# %%
df["iso_3166_2"].str.split(":")
# Out:
# 0      [ISO 3166-2, AF]
# 1      [ISO 3166-2, AX]
# 2      [ISO 3166-2, AL]
# 3      [ISO 3166-2, DZ]
# 4      [ISO 3166-2, AS]
#              ...
# 244    [ISO 3166-2, WF]
# 245    [ISO 3166-2, EH]
# 246    [ISO 3166-2, YE]
# 247    [ISO 3166-2, ZM]
# 248    [ISO 3166-2, ZW]
# Name: iso_3166_2, Length: 249, dtype: object

# %%
# how to add new columns

df["country_name"] = "Yurope"

# %%
df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
# ...

# %%
df.fillna("sub_region") == "Eastern Africa"
# Out:
#      country  code_2  code_3  country_code  iso_3166_2  continent  sub_region  \
# 0      False   False   False         False       False      False       False
# 1      False   False   False         False       False      False       False
# 2      False   False   False         False       False      False       False
# 3      False   False   False         False       False      False       False
# 4      False   False   False         False       False      False       False
# ..       ...     ...     ...           ...         ...        ...         ...
# 244    False   False   False         False       False      False       False
# 245    False   False   False         False       False      False       False
# 246    False   False   False         False       False      False       False
# 247    False   False   False         False       False      False        True
# 248    False   False   False         False       False      False        True
#
# ...

# %%
df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
# ...

# %%
df.isnull().sum()
# Out:
# country            0
# code_2             1
# code_3             0
# country_code       0
# iso_3166_2         0
# continent          9
# sub_region         9
# region_code        9
# sub_region_code    9
# country_name       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df["sub_region1"] = df["sub_region"].str.split(" ").apply(lambda x : x[0])

# %%
df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 239 entries, 0 to 248
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          239 non-null    object
#  1   code_2           239 non-null    object
#  2   code_3           239 non-null    object
#  3   country_code     239 non-null    int64
#  4   iso_3166_2       239 non-null    object
#  5   continent        239 non-null    object
#  6   sub_region       239 non-null    object
#  7   region_code      239 non-null    float64
#  8   sub_region_code  239 non-null    float64
#  9   country_name     239 non-null    object
#  10  sub_region1      239 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 22.4+ KB

# %%
df["country_code"] = df["country_code"].astype("Int32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 239 entries, 0 to 248
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          239 non-null    object
#  1   code_2           239 non-null    object
#  2   code_3           239 non-null    object
#  3   country_code     239 non-null    Int32
#  4   iso_3166_2       239 non-null    object
#  5   continent        239 non-null    object
#  6   sub_region       239 non-null    object
#  7   region_code      239 non-null    float64
#  8   sub_region_code  239 non-null    float64
#  9   country_name     239 non-null    object
#  10  sub_region1      239 non-null    object
# dtypes: Int32(1), float64(2), object(8)
# memory usage: 21.7+ KB

# %%
df["continent"].value_counts()
# Out:
# continent
# Africa      57
# Americas    55
# Asia        51
# Europe      51
# Oceania     25
# Name: count, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# Afghanistan      1
# Paraguay         1
# Niger            1
# Nigeria          1
# Niue             1
#                 ..
# Guatemala        1
# Guernsey         1
# Guinea           1
# Guinea-Bissau    1
# Zimbabwe         1
# Name: count, Length: 239, dtype: int64

# %%
df.sort_values("country")
# Out:
#             country code_2 code_3  country_code     iso_3166_2 continent  \
# 0       Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 2           Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3           Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4    American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# 5           Andorra     AD    AND            20  ISO 3166-2:AD    Europe
# ..              ...    ...    ...           ...            ...       ...
# 245  Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 246           Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 247          Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 248        Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
# 1     Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
#
#           sub_region  region_code  sub_region_code country_name sub_region1
# ...

# %%
df.sort_values("continent")
# Out:
#                       country code_2 code_3  country_code     iso_3166_2  \
# 126                     Libya     LY    LBY           434  ISO 3166-2:LY
# 140                Mauritania     MR    MRT           478  ISO 3166-2:MR
# 136                      Mali     ML    MLI           466  ISO 3166-2:ML
# 133                    Malawi     MW    MWI           454  ISO 3166-2:MW
# 132                Madagascar     MG    MDG           450  ISO 3166-2:MG
# ..                        ...    ...    ...           ...            ...
# 73                       Fiji     FJ    FJI           242  ISO 3166-2:FJ
# 203           Solomon Islands     SB    SLB            90  ISO 3166-2:SB
# 191                     Samoa     WS    WSM           882  ISO 3166-2:WS
# 164  Northern Mariana Islands     MP    MNP           580  ISO 3166-2:MP
# 4              American Samoa     AS    ASM            16  ISO 3166-2:AS
#
#     continent       sub_region  region_code  sub_region_code country_name  \
# ...

# %%
df.sort_values(["continent","country"])
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 6               Angola     AO    AGO            24  ISO 3166-2:AO    Africa
# 23               Benin     BJ    BEN           204  ISO 3166-2:BJ    Africa
# 29            Botswana     BW    BWA            72  ISO 3166-2:BW    Africa
# 35        Burkina Faso     BF    BFA           854  ISO 3166-2:BF    Africa
# ..                 ...    ...    ...           ...            ...       ...
# 223            Tokelau     TK    TKL           772  ISO 3166-2:TK   Oceania
# 224              Tonga     TO    TON           776  ISO 3166-2:TO   Oceania
# 230             Tuvalu     TV    TUV           798  ISO 3166-2:TV   Oceania
# 239            Vanuatu     VU    VUT           548  ISO 3166-2:VU   Oceania
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
#
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 248           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
# 247             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 246              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 245     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 244  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
#
# ...

# %%
df.set_index("country",inplace=True)

# %%
df
# Out:
#                   code_2 code_3  country_code     iso_3166_2 continent  \
# country
# Afghanistan           AF    AFG             4  ISO 3166-2:AF      Asia
# Åland Islands         AX    ALA           248  ISO 3166-2:AX    Europe
# Albania               AL    ALB             8  ISO 3166-2:AL    Europe
# Algeria               DZ    DZA            12  ISO 3166-2:DZ    Africa
# American Samoa        AS    ASM            16  ISO 3166-2:AS   Oceania
# ...                  ...    ...           ...            ...       ...
# Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# Western Sahara        EH    ESH           732  ISO 3166-2:EH    Africa
# Yemen                 YE    YEM           887  ISO 3166-2:YE      Asia
# Zambia                ZM    ZMB           894  ISO 3166-2:ZM    Africa
# Zimbabwe              ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
#                         sub_region  region_code  sub_region_code country_name  \
# country
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                country code_2 code_3  country_code     iso_3166_2 continent  \
# 0          Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2              Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ..                 ...    ...    ...           ...            ...       ...
# 234  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 235     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 236              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 237             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 238           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
# ...

# %%
df.index = range(1001,1240, 1)

# %%
df
# Out:
#                 country code_2 code_3  country_code     iso_3166_2 continent  \
# 1001        Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1002      Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 1003            Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 1004            Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 1005     American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
# ...                 ...    ...    ...           ...            ...       ...
# 1235  Wallis and Futuna     WF    WLF           876  ISO 3166-2:WF   Oceania
# 1236     Western Sahara     EH    ESH           732  ISO 3166-2:EH    Africa
# 1237              Yemen     YE    YEM           887  ISO 3166-2:YE      Asia
# 1238             Zambia     ZM    ZMB           894  ISO 3166-2:ZM    Africa
# 1239           Zimbabwe     ZW    ZWE           716  ISO 3166-2:ZW    Africa
#
# ...

# %%
df["region_code"].unique()
# Out:
# array([142., 150.,   2.,   9.,  19.])

# %%
temp = pd.Series([0,0,11,11,1,2,3,5,6,1,0,2,3,4,6,2,3,6,5,35])

# %%
print(temp)
# Out:
# 0      0
# 1      0
# 2     11
# 3     11
# 4      1
# 5      2
# 6      3
# 7      5
# 8      6
# 9      1
# 10     0
# 11     2
# 12     3
# 13     4
# 14     6
# 15     2
# 16     3
# 17     6
# 18     5
# 19    35
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# 11

# %%
temp.drop_duplicates(inplace=True)

# %%
temp
# Out:
# 0      0
# 2     11
# 4      1
# 5      2
# 6      3
# 7      5
# 8      6
# 13     4
# 19    35
# dtype: int64
